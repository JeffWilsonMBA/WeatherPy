# %% [markdown]
# # What's the weather like as we approach the equator?
#
# Create a Python script to visualize the weather of 500+ cities across the world of varying distance from the equator.
#
# NOTE: This project takes into account the weather inforomation from one day. Each time the code is run it randomizes 500 cities and pulls the current weather data so the results of this code will vary each time it is run.

# %%
# ependencies
import openweathermapy.core as owm
import json
import os
import csv
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import random
import requests
from citipy import citipy
from datetime import datetime as dt

# Get API key
from owm_config import api_key

# Set plot style
plt.style.use("seaborn")

# To hide warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Get 500 random cities and random distances from the equator

# %%
# Getting lat/lng values for finding cities

# Set Lat & Lng Zones to randomly pick geo coordinates
lat_zone = np.arange(-90,90,15)
lng_zone = np.arange(-180,180,15)


# Creating df for geo coordinates
locations_df = pd.DataFrame()

locations_df["Lat"] = ""
locations_df["Lng"] = ""

# From each zone, randomly pick 50 unique coordinates and adding to the dataframe.
for x in lat_zone:
    for y in lng_zone:
        x_values = list(np.arange(x,x+15,0.01))
        y_values = list(np.arange(y,y+15,0.01))
        latitude = random.sample(x_values,75)
        longitude = random.sample(y_values,75)
        lat_samples = [(x+dec_lat) for dec_lat in latitude]
        lng_samples = [y+dec_lng for dec_lng in longitude]
        locations_df = locations_df.append(pd.DataFrame.from_dict({"Lat":lat_samples,
                                       "Lng":lng_samples}))
locations_df = locations_df.reset_index(drop=True)
locations_df.shape
# Out:
# (21600, 2)

# %%
# Using citipy to get nearest city to location coordinates

locations_df["Closest City"] = ""
locations_df["Country Code"] = ""
for index,row in locations_df.iterrows():
    city = citipy.nearest_city(row["Lat"],row["Lng"])
    locations_df.set_value(index,"Closest City",city.city_name)
    locations_df.set_value(index,"Country Code",city.country_code)
locations_df.head()
# Out:
#       Lat     Lng Closest City Country Code
# 0 -167.24 -354.38        vaini           to
# 1 -178.90 -356.56        vaini           to
# 2 -177.09 -351.89        vaini           to
# 3 -173.95 -350.77        vaini           to
# 4 -169.56 -356.17        vaini           to

# %%
# Deleting random coordinates that do not match city coordinates

cities_df = locations_df.drop(['Lat', 'Lng'],axis=1)

# Dropping and duplicate cities
cities_df = cities_df.drop_duplicates()

cities_df.shape
# Out:
# (1134, 2)

# %% [markdown]
# # Don't forget to change sample size to 500 when done

# %%
# Getting 600 random cities for the remaining list
# Using 600 as the sample size to allow for cities without data to be dropped and still have 
# a minimum of 500 cities
random_cities = cities_df.sample(600)
random_cities = random_cities.reset_index(drop=True)
random_cities.head()
# Out:
#   Closest City Country Code
# 0    paraguari           py
# 1  bronnoysund           no
# 2       xining           cn
# 3    kavaratti           in
# 4        medea           dz

# %% [markdown]
# # Get weather data for the 500 random cities selected above

# %%
# Get current weather to see the JSON format
settings = {"units": "metric", "appid": api_key}
current_weather_clt = owm.get_current("Charlotte", **settings)
print(f"{json.dumps(current_weather_clt, indent=4)}")
# Out:
# {
#     "coord": {
#         "lon": -80.84,
#         "lat": 35.23
#     },
#     "weather": [
#         {
#             "id": 802,
#             "main": "Clouds",
#             "description": "scattered clouds",
#             "icon": "03d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 3.81,
#         "pressure": 1035,
#         "humidity": 56,
#         "temp_min": 3,
#         "temp_max": 5
#     },
#     "visibility": 16093,
#     "wind": {
#         "speed": 4.6,
#         "deg": 70
#     },
#     "clouds": {
#         "all": 40
#     },
#     "dt": 1522071000,
#     "sys": {
#         "type": 1,
#         "id": 1797,
#         "message": 0.0049,
#         "country": "US",
#         "sunrise": 1522063060,
#         "sunset": 1522107626
#     },
#     "id": 4460243,
#     "name": "Charlotte",
#     "cod": 200
# }

# %%
# Setting up values for OpenWeatherMap API calls
base_url = "http://api.openweathermap.org/data/2.5/weather"

params = { "appid" :api_key,"units":"metric" }

# %%
# Loop through to get Lat, Lng, Temp, Wind Speed, Humidity, and Cloudienss for each random city
# and append to random_cities

# I figured out how to hide my key
def hide_key(input_url):
    return input_url[0:53]+"<NoSeeMyKey>"+input_url[85:]

for index,row in random_cities.iterrows():
    params["q"] =f'{row["Closest City"]},{row["Country Code"]}'
    print(f"Processing Record {index+1} for: {params['q']}")
    city_weather = requests.get(base_url,params)
    print(hide_key(city_weather.url))
    city_weather  = city_weather.json()
    random_cities.set_value(index,"Latitude",city_weather.get("coord",{}).get("lat"))
    random_cities.set_value(index,"Longitude",city_weather.get("coord",{}).get("lon"))
    random_cities.set_value(index,"Temperature",city_weather.get("main",{}).get("temp_max"))
    random_cities.set_value(index,"Wind Speed",city_weather.get("wind",{}).get("speed"))
    random_cities.set_value(index,"Humidity",city_weather.get("main",{}).get("humidity"))
    random_cities.set_value(index,"Cloudiness",city_weather.get("clouds",{}).get("all"))
# Out:
# Processing Record 1 for: paraguari,py
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=paraguari%2Cpy
# Processing Record 2 for: bronnoysund,no
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bronnoysund%2Cno
# Processing Record 3 for: xining,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=xining%2Ccn
# Processing Record 4 for: kavaratti,in
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kavaratti%2Cin
# Processing Record 5 for: medea,dz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=medea%2Cdz
# Processing Record 6 for: mokolo,cm
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=mokolo%2Ccm
# Processing Record 7 for: provideniya,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=provideniya%2Cru
# Processing Record 8 for: teya,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=teya%2Cru
# Processing Record 9 for: bodo,no
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bodo%2Cno
# Processing Record 10 for: mega,et
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=mega%2Cet
# Processing Record 11 for: sunrise manor,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sunrise+manor%2Cus
# Processing Record 12 for: qandahar,af
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=qandahar%2Caf
# Processing Record 13 for: salamiyah,sy
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=salamiyah%2Csy
# Processing Record 14 for: deyang,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=deyang%2Ccn
# Processing Record 15 for: fukuma,jp
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=fukuma%2Cjp
# Processing Record 16 for: meulaboh,id
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=meulaboh%2Cid
# Processing Record 17 for: severnyy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=severnyy%2Cru
# Processing Record 18 for: santa marinella,it
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=santa+marinella%2Cit
# Processing Record 19 for: greece,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=greece%2Cus
# Processing Record 20 for: la ciotat,fr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=la+ciotat%2Cfr
# Processing Record 21 for: torbay,ca
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=torbay%2Cca
# Processing Record 22 for: kavieng,pg
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kavieng%2Cpg
# Processing Record 23 for: alamosa,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=alamosa%2Cus
# Processing Record 24 for: orgun,af
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=orgun%2Caf
# Processing Record 25 for: mingaora,pk
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=mingaora%2Cpk
# Processing Record 26 for: saint-philippe,re
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=saint-philippe%2Cre
# Processing Record 27 for: sabang,id
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sabang%2Cid
# Processing Record 28 for: havelock,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=havelock%2Cus
# Processing Record 29 for: hilo,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=hilo%2Cus
# Processing Record 30 for: nguru,ng
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=nguru%2Cng
# Processing Record 31 for: sisimiut,gl
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sisimiut%2Cgl
# Processing Record 32 for: angoche,mz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=angoche%2Cmz
# Processing Record 33 for: cidreira,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=cidreira%2Cbr
# Processing Record 34 for: phangnga,th
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=phangnga%2Cth
# Processing Record 35 for: poum,nc
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=poum%2Cnc
# Processing Record 36 for: margate,za
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=margate%2Cza
# Processing Record 37 for: bredasdorp,za
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bredasdorp%2Cza
# Processing Record 38 for: valls,es
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=valls%2Ces
# Processing Record 39 for: palabuhanratu,id
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=palabuhanratu%2Cid
# Processing Record 40 for: apple valley,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=apple+valley%2Cus
# Processing Record 41 for: bentong,my
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bentong%2Cmy
# Processing Record 42 for: waqqas,jo
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=waqqas%2Cjo
# Processing Record 43 for: lagos,ng
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=lagos%2Cng
# Processing Record 44 for: san cristobal,ec
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=san+cristobal%2Cec
# Processing Record 45 for: preston,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=preston%2Cus
# Processing Record 46 for: rome,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=rome%2Cus
# Processing Record 47 for: maracai,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=maracai%2Cbr
# Processing Record 48 for: sakakah,sa
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sakakah%2Csa
# Processing Record 49 for: kinablangan,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kinablangan%2Cph
# Processing Record 50 for: kahului,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kahului%2Cus
# Processing Record 51 for: apac,ug
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=apac%2Cug
# Processing Record 52 for: brokopondo,sr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=brokopondo%2Csr
# Processing Record 53 for: gilgit,pk
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=gilgit%2Cpk
# Processing Record 54 for: jacksonville,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=jacksonville%2Cus
# Processing Record 55 for: dingli,mt
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=dingli%2Cmt
# Processing Record 56 for: kuantan,my
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kuantan%2Cmy
# Processing Record 57 for: san isidro,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=san+isidro%2Cph
# Processing Record 58 for: leningradskiy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=leningradskiy%2Cru
# Processing Record 59 for: fuerte olimpo,py
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=fuerte+olimpo%2Cpy
# Processing Record 60 for: kuala terengganu,my
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kuala+terengganu%2Cmy
# Processing Record 61 for: funadhoo,mv
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=funadhoo%2Cmv
# Processing Record 62 for: tsiroanomandidy,mg
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=tsiroanomandidy%2Cmg
# Processing Record 63 for: timizart,dz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=timizart%2Cdz
# Processing Record 64 for: amderma,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=amderma%2Cru
# Processing Record 65 for: baculin,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=baculin%2Cph
# Processing Record 66 for: skalistyy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=skalistyy%2Cru
# Processing Record 67 for: erdemli,tr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=erdemli%2Ctr
# Processing Record 68 for: ayolas,py
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ayolas%2Cpy
# Processing Record 69 for: bereznik,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bereznik%2Cru
# Processing Record 70 for: labutta,mm
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=labutta%2Cmm
# Processing Record 71 for: adrar,dz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=adrar%2Cdz
# Processing Record 72 for: appleton,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=appleton%2Cus
# Processing Record 73 for: thompson,ca
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=thompson%2Cca
# Processing Record 74 for: santiago,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=santiago%2Cph
# Processing Record 75 for: santa cruz,cr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=santa+cruz%2Ccr
# Processing Record 76 for: qaanaaq,gl
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=qaanaaq%2Cgl
# Processing Record 77 for: kousseri,cm
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kousseri%2Ccm
# Processing Record 78 for: tiarei,pf
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=tiarei%2Cpf
# Processing Record 79 for: bubaque,gw
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bubaque%2Cgw
# Processing Record 80 for: aras,no
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=aras%2Cno
# Processing Record 81 for: mbour,sn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=mbour%2Csn
# Processing Record 82 for: huilong,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=huilong%2Ccn
# Processing Record 83 for: egvekinot,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=egvekinot%2Cru
# Processing Record 84 for: nuuk,gl
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=nuuk%2Cgl
# Processing Record 85 for: kangaatsiaq,gl
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kangaatsiaq%2Cgl
# Processing Record 86 for: obigarm,tj
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=obigarm%2Ctj
# Processing Record 87 for: banda aceh,id
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=banda+aceh%2Cid
# Processing Record 88 for: boa esperanca,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=boa+esperanca%2Cbr
# Processing Record 89 for: micomeseng,gq
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=micomeseng%2Cgq
# Processing Record 90 for: monchegorsk,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=monchegorsk%2Cru
# Processing Record 91 for: ossora,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ossora%2Cru
# Processing Record 92 for: flagstaff,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=flagstaff%2Cus
# Processing Record 93 for: gusau,ng
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=gusau%2Cng
# Processing Record 94 for: kapoeta,sd
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kapoeta%2Csd
# Processing Record 95 for: pevek,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=pevek%2Cru
# Processing Record 96 for: povenets,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=povenets%2Cru
# Processing Record 97 for: terrasini,it
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=terrasini%2Cit
# Processing Record 98 for: safita,sy
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=safita%2Csy
# Processing Record 99 for: valley,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=valley%2Cus
# Processing Record 100 for: brufut,gm
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=brufut%2Cgm
# Processing Record 101 for: gambela,et
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=gambela%2Cet
# Processing Record 102 for: sharan,af
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sharan%2Caf
# Processing Record 103 for: punta arenas,cl
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=punta+arenas%2Ccl
# Processing Record 104 for: belushya guba,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=belushya+guba%2Cru
# Processing Record 105 for: attawapiskat,ca
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=attawapiskat%2Cca
# Processing Record 106 for: muisne,ec
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=muisne%2Cec
# Processing Record 107 for: haines junction,ca
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=haines+junction%2Cca
# Processing Record 108 for: bolu,tr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bolu%2Ctr
# Processing Record 109 for: srednekolymsk,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=srednekolymsk%2Cru
# Processing Record 110 for: springville,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=springville%2Cus
# Processing Record 111 for: omsukchan,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=omsukchan%2Cru
# Processing Record 112 for: ponta delgada,pt
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ponta+delgada%2Cpt
# Processing Record 113 for: mhlambanyatsi,sz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=mhlambanyatsi%2Csz
# Processing Record 114 for: camacha,pt
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=camacha%2Cpt
# Processing Record 115 for: peruibe,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=peruibe%2Cbr
# Processing Record 116 for: surgut,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=surgut%2Cru
# Processing Record 117 for: dosso,ne
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=dosso%2Cne
# Processing Record 118 for: sao mateus do sul,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sao+mateus+do+sul%2Cbr
# Processing Record 119 for: miandrivazo,mg
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=miandrivazo%2Cmg
# Processing Record 120 for: ruidoso,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ruidoso%2Cus
# Processing Record 121 for: bonito,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bonito%2Cbr
# Processing Record 122 for: ilulissat,gl
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ilulissat%2Cgl
# Processing Record 123 for: khorixas,na
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=khorixas%2Cna
# Processing Record 124 for: uwajima,jp
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=uwajima%2Cjp
# Processing Record 125 for: jacutinga,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=jacutinga%2Cbr
# Processing Record 126 for: promyshlennyy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=promyshlennyy%2Cru
# Processing Record 127 for: morondava,mg
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=morondava%2Cmg
# Processing Record 128 for: marsabit,ke
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=marsabit%2Cke
# Processing Record 129 for: winslow,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=winslow%2Cus
# Processing Record 130 for: oriximina,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=oriximina%2Cbr
# Processing Record 131 for: pedernales,ec
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=pedernales%2Cec
# Processing Record 132 for: potiskum,ng
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=potiskum%2Cng
# Processing Record 133 for: jackson,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=jackson%2Cus
# Processing Record 134 for: sumter,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sumter%2Cus
# Processing Record 135 for: cabo san lucas,mx
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=cabo+san+lucas%2Cmx
# Processing Record 136 for: kaitong,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kaitong%2Ccn
# Processing Record 137 for: paamiut,gl
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=paamiut%2Cgl
# Processing Record 138 for: huite,gt
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=huite%2Cgt
# Processing Record 139 for: marabba,sd
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=marabba%2Csd
# Processing Record 140 for: trabzon,tr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=trabzon%2Ctr
# Processing Record 141 for: san quintin,mx
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=san+quintin%2Cmx
# Processing Record 142 for: bairiki,ki
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bairiki%2Cki
# Processing Record 143 for: dubti,et
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=dubti%2Cet
# Processing Record 144 for: uniontown,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=uniontown%2Cus
# Processing Record 145 for: shelbyville,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=shelbyville%2Cus
# Processing Record 146 for: tarnogskiy gorodok,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=tarnogskiy+gorodok%2Cru
# Processing Record 147 for: burica,pa
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=burica%2Cpa
# Processing Record 148 for: bilibino,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bilibino%2Cru
# Processing Record 149 for: bourbonnais,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bourbonnais%2Cus
# Processing Record 150 for: kysyl-syr,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kysyl-syr%2Cru
# Processing Record 151 for: mackay,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=mackay%2Cau
# Processing Record 152 for: tigre,pa
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=tigre%2Cpa
# Processing Record 153 for: zanesville,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=zanesville%2Cus
# Processing Record 154 for: cherskiy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=cherskiy%2Cru
# Processing Record 155 for: mount gambier,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=mount+gambier%2Cau
# Processing Record 156 for: noumea,nc
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=noumea%2Cnc
# Processing Record 157 for: rosarito,mx
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=rosarito%2Cmx
# Processing Record 158 for: linjiang,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=linjiang%2Ccn
# Processing Record 159 for: picton,ca
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=picton%2Cca
# Processing Record 160 for: nikolskoye,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=nikolskoye%2Cru
# Processing Record 161 for: beira,mz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=beira%2Cmz
# Processing Record 162 for: ranong,th
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ranong%2Cth
# Processing Record 163 for: grants,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=grants%2Cus
# Processing Record 164 for: mazara del vallo,it
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=mazara+del+vallo%2Cit
# Processing Record 165 for: hay river,ca
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=hay+river%2Cca
# Processing Record 166 for: bundaberg,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bundaberg%2Cau
# Processing Record 167 for: berlin,hn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=berlin%2Chn
# Processing Record 168 for: sisophon,kh
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sisophon%2Ckh
# Processing Record 169 for: zhanakorgan,kz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=zhanakorgan%2Ckz
# Processing Record 170 for: nome,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=nome%2Cus
# Processing Record 171 for: florianopolis,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=florianopolis%2Cbr
# Processing Record 172 for: casa grande,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=casa+grande%2Cus
# Processing Record 173 for: maneadero,mx
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=maneadero%2Cmx
# Processing Record 174 for: benxi,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=benxi%2Ccn
# Processing Record 175 for: barberton,za
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=barberton%2Cza
# Processing Record 176 for: bindura,zw
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bindura%2Czw
# Processing Record 177 for: funchal,pt
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=funchal%2Cpt
# Processing Record 178 for: zaria,ng
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=zaria%2Cng
# Processing Record 179 for: tooele,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=tooele%2Cus
# Processing Record 180 for: coachella,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=coachella%2Cus
# Processing Record 181 for: matameye,ne
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=matameye%2Cne
# Processing Record 182 for: san antonio,hn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=san+antonio%2Chn
# Processing Record 183 for: rosetta,eg
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=rosetta%2Ceg
# Processing Record 184 for: zapolyarnyy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=zapolyarnyy%2Cru
# Processing Record 185 for: hofn,is
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=hofn%2Cis
# Processing Record 186 for: nadvoitsy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=nadvoitsy%2Cru
# Processing Record 187 for: garachine,pa
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=garachine%2Cpa
# Processing Record 188 for: murmashi,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=murmashi%2Cru
# Processing Record 189 for: aneho,tg
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=aneho%2Ctg
# Processing Record 190 for: prata,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=prata%2Cbr
# Processing Record 191 for: raudeberg,no
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=raudeberg%2Cno
# Processing Record 192 for: namatanai,pg
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=namatanai%2Cpg
# Processing Record 193 for: voh,nc
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=voh%2Cnc
# Processing Record 194 for: caraguatatuba,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=caraguatatuba%2Cbr
# Processing Record 195 for: presidente epitacio,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=presidente+epitacio%2Cbr
# Processing Record 196 for: te anau,nz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=te+anau%2Cnz
# Processing Record 197 for: oshnaviyeh,ir
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=oshnaviyeh%2Cir
# Processing Record 198 for: rudnyy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=rudnyy%2Cru
# Processing Record 199 for: san antero,co
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=san+antero%2Cco
# Processing Record 200 for: grand-santi,gf
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=grand-santi%2Cgf
# Processing Record 201 for: moyale,ke
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=moyale%2Cke
# Processing Record 202 for: laguna de perlas,ni
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=laguna+de+perlas%2Cni
# Processing Record 203 for: beloha,mg
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=beloha%2Cmg
# Processing Record 204 for: damulog,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=damulog%2Cph
# Processing Record 205 for: kaberamaido,ug
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kaberamaido%2Cug
# Processing Record 206 for: qasigiannguit,gl
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=qasigiannguit%2Cgl
# Processing Record 207 for: la vergne,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=la+vergne%2Cus
# Processing Record 208 for: viligili,mv
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=viligili%2Cmv
# Processing Record 209 for: oytal,kz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=oytal%2Ckz
# Processing Record 210 for: anloga,gh
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=anloga%2Cgh
# Processing Record 211 for: oxford,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=oxford%2Cus
# Processing Record 212 for: qarqin,af
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=qarqin%2Caf
# Processing Record 213 for: doctor juan leon mallorquin,py
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=doctor+juan+leon+mallorquin%2Cpy
# Processing Record 214 for: goure,ne
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=goure%2Cne
# Processing Record 215 for: roros,no
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=roros%2Cno
# Processing Record 216 for: canon city,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=canon+city%2Cus
# Processing Record 217 for: kamennomostskoye,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kamennomostskoye%2Cru
# Processing Record 218 for: port hedland,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=port+hedland%2Cau
# Processing Record 219 for: geresk,af
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=geresk%2Caf
# Processing Record 220 for: labuhan,id
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=labuhan%2Cid
# Processing Record 221 for: cucuyagua,hn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=cucuyagua%2Chn
# Processing Record 222 for: ust-shonosha,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ust-shonosha%2Cru
# Processing Record 223 for: ampanihy,mg
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ampanihy%2Cmg
# Processing Record 224 for: yenagoa,ng
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=yenagoa%2Cng
# Processing Record 225 for: coahuayana,mx
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=coahuayana%2Cmx
# Processing Record 226 for: kalamazoo,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kalamazoo%2Cus
# Processing Record 227 for: salekhard,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=salekhard%2Cru
# Processing Record 228 for: maputo,mz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=maputo%2Cmz
# Processing Record 229 for: tuktoyaktuk,ca
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=tuktoyaktuk%2Cca
# Processing Record 230 for: batagay-alyta,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=batagay-alyta%2Cru
# Processing Record 231 for: kapaa,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kapaa%2Cus
# Processing Record 232 for: west lorne,ca
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=west+lorne%2Cca
# Processing Record 233 for: isangel,vu
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=isangel%2Cvu
# Processing Record 234 for: vila velha,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=vila+velha%2Cbr
# Processing Record 235 for: pingzhuang,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=pingzhuang%2Ccn
# Processing Record 236 for: goderich,sl
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=goderich%2Csl
# Processing Record 237 for: pasighat,in
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=pasighat%2Cin
# Processing Record 238 for: tres coroas,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=tres+coroas%2Cbr
# Processing Record 239 for: fowa,eg
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=fowa%2Ceg
# Processing Record 240 for: clyde river,ca
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=clyde+river%2Cca
# Processing Record 241 for: villeneuve-sur-lot,fr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=villeneuve-sur-lot%2Cfr
# Processing Record 242 for: nuqui,co
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=nuqui%2Cco
# Processing Record 243 for: vaitupu,wf
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=vaitupu%2Cwf
# Processing Record 244 for: lang suan,th
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=lang+suan%2Cth
# Processing Record 245 for: grindavik,is
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=grindavik%2Cis
# Processing Record 246 for: iturama,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=iturama%2Cbr
# Processing Record 247 for: giyon,et
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=giyon%2Cet
# Processing Record 248 for: tijuana,mx
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=tijuana%2Cmx
# Processing Record 249 for: lethem,gy
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=lethem%2Cgy
# Processing Record 250 for: coolum beach,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=coolum+beach%2Cau
# Processing Record 251 for: pisco,pe
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=pisco%2Cpe
# Processing Record 252 for: erie,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=erie%2Cus
# Processing Record 253 for: bida,ng
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bida%2Cng
# Processing Record 254 for: bure,et
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bure%2Cet
# Processing Record 255 for: waipawa,nz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=waipawa%2Cnz
# Processing Record 256 for: los llanos de aridane,es
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=los+llanos+de+aridane%2Ces
# Processing Record 257 for: kerki,tm
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kerki%2Ctm
# Processing Record 258 for: cerrito,py
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=cerrito%2Cpy
# Processing Record 259 for: dhidhdhoo,mv
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=dhidhdhoo%2Cmv
# Processing Record 260 for: rancho palos verdes,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=rancho+palos+verdes%2Cus
# Processing Record 261 for: mudanjiang,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=mudanjiang%2Ccn
# Processing Record 262 for: viransehir,tr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=viransehir%2Ctr
# Processing Record 263 for: betioky,mg
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=betioky%2Cmg
# Processing Record 264 for: zhigansk,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=zhigansk%2Cru
# Processing Record 265 for: monte carmelo,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=monte+carmelo%2Cbr
# Processing Record 266 for: ngunguru,nz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ngunguru%2Cnz
# Processing Record 267 for: verkhoyansk,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=verkhoyansk%2Cru
# Processing Record 268 for: tazovskiy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=tazovskiy%2Cru
# Processing Record 269 for: premia de mar,es
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=premia+de+mar%2Ces
# Processing Record 270 for: lima,pe
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=lima%2Cpe
# Processing Record 271 for: ninotsminda,ge
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ninotsminda%2Cge
# Processing Record 272 for: birin,dz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=birin%2Cdz
# Processing Record 273 for: manado,id
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=manado%2Cid
# Processing Record 274 for: nampula,mz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=nampula%2Cmz
# Processing Record 275 for: winnemucca,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=winnemucca%2Cus
# Processing Record 276 for: rabak,sd
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=rabak%2Csd
# Processing Record 277 for: waycross,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=waycross%2Cus
# Processing Record 278 for: taltal,cl
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=taltal%2Ccl
# Processing Record 279 for: sentyabrskiy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sentyabrskiy%2Cru
# Processing Record 280 for: tucuma,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=tucuma%2Cbr
# Processing Record 281 for: souillac,mu
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=souillac%2Cmu
# Processing Record 282 for: muyezerskiy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=muyezerskiy%2Cru
# Processing Record 283 for: puerto colombia,co
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=puerto+colombia%2Cco
# Processing Record 284 for: holland,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=holland%2Cus
# Processing Record 285 for: wanlaweyn,so
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=wanlaweyn%2Cso
# Processing Record 286 for: kristiansund,no
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kristiansund%2Cno
# Processing Record 287 for: anderson,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=anderson%2Cus
# Processing Record 288 for: yushan,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=yushan%2Ccn
# Processing Record 289 for: borama,so
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=borama%2Cso
# Processing Record 290 for: otukpo,ng
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=otukpo%2Cng
# Processing Record 291 for: decatur,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=decatur%2Cus
# Processing Record 292 for: cotonou,bj
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=cotonou%2Cbj
# Processing Record 293 for: lodwar,ke
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=lodwar%2Cke
# Processing Record 294 for: pahrump,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=pahrump%2Cus
# Processing Record 295 for: geraldton,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=geraldton%2Cau
# Processing Record 296 for: nadym,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=nadym%2Cru
# Processing Record 297 for: arandis,na
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=arandis%2Cna
# Processing Record 298 for: fallon,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=fallon%2Cus
# Processing Record 299 for: luba,gq
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=luba%2Cgq
# Processing Record 300 for: fortuna foothills,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=fortuna+foothills%2Cus
# Processing Record 301 for: brawley,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=brawley%2Cus
# Processing Record 302 for: sochi,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sochi%2Cru
# Processing Record 303 for: pafos,cy
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=pafos%2Ccy
# Processing Record 304 for: tottori,jp
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=tottori%2Cjp
# Processing Record 305 for: yulara,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=yulara%2Cau
# Processing Record 306 for: fuxin,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=fuxin%2Ccn
# Processing Record 307 for: itapirapua,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=itapirapua%2Cbr
# Processing Record 308 for: porto uniao,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=porto+uniao%2Cbr
# Processing Record 309 for: murgab,tm
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=murgab%2Ctm
# Processing Record 310 for: kalaswala,pk
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kalaswala%2Cpk
# Processing Record 311 for: mergui,mm
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=mergui%2Cmm
# Processing Record 312 for: guapore,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=guapore%2Cbr
# Processing Record 313 for: sarangani,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sarangani%2Cph
# Processing Record 314 for: bitung,id
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bitung%2Cid
# Processing Record 315 for: mingyue,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=mingyue%2Ccn
# Processing Record 316 for: sarakhs,ir
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sarakhs%2Cir
# Processing Record 317 for: statesville,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=statesville%2Cus
# Processing Record 318 for: libreville,ga
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=libreville%2Cga
# Processing Record 319 for: la union,gt
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=la+union%2Cgt
# Processing Record 320 for: tolaga bay,nz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=tolaga+bay%2Cnz
# Processing Record 321 for: stykkisholmur,is
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=stykkisholmur%2Cis
# Processing Record 322 for: qaqortoq,gl
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=qaqortoq%2Cgl
# Processing Record 323 for: olbia,it
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=olbia%2Cit
# Processing Record 324 for: wadi musa,jo
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=wadi+musa%2Cjo
# Processing Record 325 for: corn island,ni
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=corn+island%2Cni
# Processing Record 326 for: noyabrsk,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=noyabrsk%2Cru
# Processing Record 327 for: portobelo,pa
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=portobelo%2Cpa
# Processing Record 328 for: karakose,tr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=karakose%2Ctr
# Processing Record 329 for: taclobo,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=taclobo%2Cph
# Processing Record 330 for: pitogo,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=pitogo%2Cph
# Processing Record 331 for: gravdal,no
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=gravdal%2Cno
# Processing Record 332 for: oistins,bb
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=oistins%2Cbb
# Processing Record 333 for: opuwo,na
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=opuwo%2Cna
# Processing Record 334 for: say,ne
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=say%2Cne
# Processing Record 335 for: ouargaye,bf
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ouargaye%2Cbf
# Processing Record 336 for: barao de melgaco,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=barao+de+melgaco%2Cbr
# Processing Record 337 for: vorgashor,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=vorgashor%2Cru
# Processing Record 338 for: kigorobya,ug
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kigorobya%2Cug
# Processing Record 339 for: oppdal,no
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=oppdal%2Cno
# Processing Record 340 for: skagastrond,is
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=skagastrond%2Cis
# Processing Record 341 for: wukari,ng
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=wukari%2Cng
# Processing Record 342 for: tchaourou,bj
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=tchaourou%2Cbj
# Processing Record 343 for: college,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=college%2Cus
# Processing Record 344 for: taos,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=taos%2Cus
# Processing Record 345 for: puerto ayora,ec
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=puerto+ayora%2Cec
# Processing Record 346 for: quepos,cr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=quepos%2Ccr
# Processing Record 347 for: kirakira,sb
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kirakira%2Csb
# Processing Record 348 for: kulhudhuffushi,mv
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kulhudhuffushi%2Cmv
# Processing Record 349 for: sapa,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sapa%2Cph
# Processing Record 350 for: pilar,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=pilar%2Cph
# Processing Record 351 for: sinop,tr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sinop%2Ctr
# Processing Record 352 for: asosa,et
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=asosa%2Cet
# Processing Record 353 for: hede,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=hede%2Ccn
# Processing Record 354 for: meyungs,pw
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=meyungs%2Cpw
# Processing Record 355 for: porto empedocle,it
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=porto+empedocle%2Cit
# Processing Record 356 for: formosa,ar
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=formosa%2Car
# Processing Record 357 for: kaseda,jp
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kaseda%2Cjp
# Processing Record 358 for: sistranda,no
# ...
# Processing Record 482 for: sacramento,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sacramento%2Cbr
# Processing Record 483 for: general delgado,py
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=general+delgado%2Cpy
# Processing Record 484 for: kamennomostskiy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kamennomostskiy%2Cru
# Processing Record 485 for: chupa,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=chupa%2Cru
# Processing Record 486 for: akropong,gh
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=akropong%2Cgh
# Processing Record 487 for: payo,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=payo%2Cph
# Processing Record 488 for: hihifo,to
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=hihifo%2Cto
# Processing Record 489 for: bagado,co
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bagado%2Cco
# Processing Record 490 for: staunton,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=staunton%2Cus
# Processing Record 491 for: eureka,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=eureka%2Cus
# Processing Record 492 for: rexburg,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=rexburg%2Cus
# Processing Record 493 for: oktyabrskoye,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=oktyabrskoye%2Cru
# Processing Record 494 for: tala,eg
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=tala%2Ceg
# Processing Record 495 for: mahebourg,mu
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=mahebourg%2Cmu
# Processing Record 496 for: hirado,jp
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=hirado%2Cjp
# Processing Record 497 for: albuquerque,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=albuquerque%2Cus
# Processing Record 498 for: kununurra,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kununurra%2Cau
# Processing Record 499 for: kudahuvadhoo,mv
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kudahuvadhoo%2Cmv
# Processing Record 500 for: iralaya,hn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=iralaya%2Chn
# Processing Record 501 for: kastamonu,tr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kastamonu%2Ctr
# Processing Record 502 for: felix perez cardozo,py
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=felix+perez+cardozo%2Cpy
# Processing Record 503 for: ifo,ng
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ifo%2Cng
# Processing Record 504 for: pandan,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=pandan%2Cph
# Processing Record 505 for: mahaicony,gy
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=mahaicony%2Cgy
# Processing Record 506 for: zaozerne,ua
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=zaozerne%2Cua
# Processing Record 507 for: guaira,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=guaira%2Cbr
# Processing Record 508 for: marienburg,sr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=marienburg%2Csr
# Processing Record 509 for: busselton,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=busselton%2Cau
# Processing Record 510 for: lenger,kz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=lenger%2Ckz
# Processing Record 511 for: north myrtle beach,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=north+myrtle+beach%2Cus
# Processing Record 512 for: xifeng,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=xifeng%2Ccn
# Processing Record 513 for: beroroha,mg
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=beroroha%2Cmg
# Processing Record 514 for: olafsvik,is
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=olafsvik%2Cis
# Processing Record 515 for: aydun,jo
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=aydun%2Cjo
# Processing Record 516 for: allada,bj
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=allada%2Cbj
# Processing Record 517 for: ballina,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ballina%2Cau
# Processing Record 518 for: georgetown,gy
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=georgetown%2Cgy
# Processing Record 519 for: gisborne,nz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=gisborne%2Cnz
# Processing Record 520 for: juba,sd
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=juba%2Csd
# Processing Record 521 for: quballat,tn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=quballat%2Ctn
# Processing Record 522 for: leland,no
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=leland%2Cno
# Processing Record 523 for: yeppoon,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=yeppoon%2Cau
# Processing Record 524 for: price,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=price%2Cus
# Processing Record 525 for: blonduos,is
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=blonduos%2Cis
# Processing Record 526 for: norman wells,ca
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=norman+wells%2Cca
# Processing Record 527 for: evanston,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=evanston%2Cus
# Processing Record 528 for: henderson,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=henderson%2Cus
# Processing Record 529 for: gorontalo,id
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=gorontalo%2Cid
# Processing Record 530 for: georgetown,sh
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=georgetown%2Csh
# Processing Record 531 for: otavalo,ec
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=otavalo%2Cec
# Processing Record 532 for: mabaruma,gy
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=mabaruma%2Cgy
# Processing Record 533 for: kubuta,sz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kubuta%2Csz
# Processing Record 534 for: bonthe,sl
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bonthe%2Csl
# Processing Record 535 for: onega,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=onega%2Cru
# Processing Record 536 for: san roque,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=san+roque%2Cph
# Processing Record 537 for: tuatapere,nz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=tuatapere%2Cnz
# Processing Record 538 for: bahir dar,et
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bahir+dar%2Cet
# Processing Record 539 for: ascoli piceno,it
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ascoli+piceno%2Cit
# Processing Record 540 for: sovetskiy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sovetskiy%2Cru
# Processing Record 541 for: mocambique,mz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=mocambique%2Cmz
# Processing Record 542 for: sao joao da barra,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sao+joao+da+barra%2Cbr
# Processing Record 543 for: bandarbeyla,so
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bandarbeyla%2Cso
# Processing Record 544 for: chuy,uy
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=chuy%2Cuy
# Processing Record 545 for: biu,ng
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=biu%2Cng
# Processing Record 546 for: aklavik,ca
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=aklavik%2Cca
# Processing Record 547 for: pishin,pk
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=pishin%2Cpk
# Processing Record 548 for: alto piquiri,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=alto+piquiri%2Cbr
# Processing Record 549 for: luderitz,na
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=luderitz%2Cna
# Processing Record 550 for: balaipungut,id
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=balaipungut%2Cid
# Processing Record 551 for: berbera,so
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=berbera%2Cso
# Processing Record 552 for: lorengau,pg
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=lorengau%2Cpg
# Processing Record 553 for: agbor,ng
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=agbor%2Cng
# Processing Record 554 for: mikhaylovka,kz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=mikhaylovka%2Ckz
# Processing Record 555 for: kodinsk,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kodinsk%2Cru
# Processing Record 556 for: naranjal,py
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=naranjal%2Cpy
# Processing Record 557 for: solovetskiy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=solovetskiy%2Cru
# Processing Record 558 for: ziarat,pk
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ziarat%2Cpk
# Processing Record 559 for: alamogordo,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=alamogordo%2Cus
# Processing Record 560 for: phuket,th
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=phuket%2Cth
# Processing Record 561 for: stabat,id
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=stabat%2Cid
# Processing Record 562 for: kapchorwa,ug
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kapchorwa%2Cug
# Processing Record 563 for: dover,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=dover%2Cus
# Processing Record 564 for: yar-sale,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=yar-sale%2Cru
# Processing Record 565 for: umzimvubu,za
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=umzimvubu%2Cza
# Processing Record 566 for: aasiaat,gl
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=aasiaat%2Cgl
# Processing Record 567 for: hovd,mn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=hovd%2Cmn
# Processing Record 568 for: seoul,kr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=seoul%2Ckr
# Processing Record 569 for: edd,er
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=edd%2Cer
# Processing Record 570 for: ode,ng
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ode%2Cng
# Processing Record 571 for: mineiros,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=mineiros%2Cbr
# Processing Record 572 for: kouqian,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kouqian%2Ccn
# Processing Record 573 for: pangnirtung,ca
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=pangnirtung%2Cca
# Processing Record 574 for: hinesville,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=hinesville%2Cus
# Processing Record 575 for: sfantu gheorghe,ro
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sfantu+gheorghe%2Cro
# Processing Record 576 for: berdigestyakh,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=berdigestyakh%2Cru
# Processing Record 577 for: east london,za
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=east+london%2Cza
# Processing Record 578 for: kampot,kh
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kampot%2Ckh
# Processing Record 579 for: barcelona,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=barcelona%2Cph
# Processing Record 580 for: mahajanga,mg
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=mahajanga%2Cmg
# Processing Record 581 for: puksoozero,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=puksoozero%2Cru
# Processing Record 582 for: adwa,et
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=adwa%2Cet
# Processing Record 583 for: greensburg,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=greensburg%2Cus
# Processing Record 584 for: dangara,tj
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=dangara%2Ctj
# Processing Record 585 for: yatou,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=yatou%2Ccn
# Processing Record 586 for: daultala,pk
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=daultala%2Cpk
# Processing Record 587 for: muroto,jp
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=muroto%2Cjp
# Processing Record 588 for: richards bay,za
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=richards+bay%2Cza
# Processing Record 589 for: bata,gq
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bata%2Cgq
# Processing Record 590 for: dunedin,nz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=dunedin%2Cnz
# Processing Record 591 for: peniche,pt
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=peniche%2Cpt
# Processing Record 592 for: acari,pe
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=acari%2Cpe
# Processing Record 593 for: macia,mz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=macia%2Cmz
# Processing Record 594 for: murindo,co
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=murindo%2Cco
# Processing Record 595 for: alice springs,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=alice+springs%2Cau
# Processing Record 596 for: silifke,tr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=silifke%2Ctr
# Processing Record 597 for: yugorsk,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=yugorsk%2Cru
# Processing Record 598 for: qabis,tn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=qabis%2Ctn
# Processing Record 599 for: hervey bay,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=hervey+bay%2Cau
# Processing Record 600 for: gallup,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=gallup%2Cus

# %%
# Drop cities with missing information and create csv file
random_cities = random_cities.dropna()
random_cities.to_csv("city_weather_data.csv")
print(random_cities.shape)
random_cities.head()
# Out:
# (537, 8)
#   Closest City Country Code  Latitude  Longitude  Temperature  Wind Speed  \
# 0    paraguari           py    -25.62     -57.15        18.00        4.60
# 1  bronnoysund           no     65.46      12.20         0.00        1.50
# 2       xining           cn     36.62     101.77        -1.75        1.11
# 3    kavaratti           in     10.57      72.64        29.38        4.21
# 4        medea           dz     36.27       2.77        14.00        2.60
#
#    Humidity  Cloudiness
# 0      68.0         0.0
# 1     100.0        40.0
# 2      71.0         0.0
# 3     100.0         0.0
# 4      76.0        40.0

# %% [markdown]
# # Scatterplots to visualize data for data analysis
#
#
#
#
# # Maximum Temperature versus Latitude

# %%
# Temperature vs Latitude 
random_cities.plot(kind="scatter",x="Latitude",y="Temperature",grid=True,color="blue")
plt.title(" Maximum Temperature (Celcius) versus Latitude")
plt.ylabel("Maximum Temperature (Celcius)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-90,90])
plt.axvline(0, color='black',alpha=0.5)
plt.savefig("Maximum Temperature vs Latitude")
plt.show()

# %% [markdown]
# # Maximum Temperature versus Latitude - Observations
# Temperatures do tend to be higher in cities that are closer to the equator.  You can see a downward trend in temperatures the farther away to go from the equator, especially in the northern hemisphere.  There are more cities in the sample population that are closer to the north pole compared to the south pole, which is likely because there are more cities in the northern hemisphere.
#
#
# # Humidity versus Latitude

# %%
# Humidity vs Latitude 

random_cities.plot(kind="scatter",x="Latitude",y="Humidity",grid=True,color="blue")
plt.title("Humidity versus Latitude")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-90,90])
plt.axvline(0, color='black',alpha=0.5)
plt.savefig("Humidity vs Latitude")
plt.show()

# %% [markdown]
# # Humidity versus Latitude - Observations
# In this sample population there does appear to be a slight trend that the farther away from the equator, the lowest humidity levels tend to increase.  As this trend is very slight there could be some population bias.
#
#
# # Wind Speed versus Latitude

# %%
# Wind Speed vs Latitude
random_cities["Wind Speed"] = pd.to_numeric(random_cities["Wind Speed"])
random_cities.plot(kind="scatter",x="Latitude",y="Wind Speed",grid=True,color="blue")
plt.title("Wind Spead versus Latitude")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-90,90])
plt.axvline(0, color='black',alpha=0.5)
plt.savefig("Wind speed vs Latitude")
plt.show()

# %% [markdown]
# # Wind Speed versus Latitude - Observations
# There does not appear to be a significant change in wind speed based on distace from the equator.  Generally, wind speeds are consistently below 10 KPH.  There are a few values over 10 KPH the farther away from the equator you go; however, there are very few and these could be outliers.
#
#
# # Cloudiness versus Latitude

# %%
# Cloudiness vs Latitude
random_cities["Cloudiness"] = pd.to_numeric(random_cities["Cloudiness"])
random_cities.plot(kind="scatter",x="Latitude",y="Cloudiness",grid=True,color="blue")
plt.title("Cloudiness versus Latitude")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-90,90])
plt.axvline(0, color='black',alpha=0.5)
plt.savefig("Cloudiness vs Latitude")
plt.show()

# %% [markdown]
# # Cloudiness versus Latitude - Observations
# No significant trends can be seen in the data for this sample population.  Distance from the equator does not appear to be a factor in cloudiness.

# %%
# Temperature approaching equator
size_temp = np.round((((random_cities.Temperature)/100)**2)*10,2)

random_cities.plot(kind="scatter",x="Longitude",y="Latitude",grid=True, edgecolor="black",
                     c=size_temp,s=200,cmap=plt.cm.YlOrRd)
plt.xlabel("Longitude")
plt.tight_layout()
plt.title("Temperature along Longitude and Latitude")
plt.ylabel("Latitude")
plt.xlabel("Longitude")
plt.ylim([-90,90])
plt.grid(True)

plt.xlim([-200,200])
plt.subplots_adjust(bottom=.25, left=.25)

plt.axhline(0, color='black',alpha=0.5)
plt.savefig("Temperature approaching Equator")

plt.show()
