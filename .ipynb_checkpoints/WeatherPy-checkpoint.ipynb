# %% [markdown]
# # What's the weather like as we approach the equator?
#
# Create a Python script to visualize the weather of 500+ cities across the world of varying distance from the equator.
#
# NOTE: This project takes into account the weather inforomation from one day. Each time the code is run it randomizes 500 cities and pulls the current weather data so the results of this code will vary each time it is run.

# %%
# ependencies
import openweathermapy.core as owm
import json
import os
import csv
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import random
import requests
from citipy import citipy
from datetime import datetime as dt

# Get API key
from owm_config import api_key

# Set plot style
plt.style.use("seaborn")

# To hide warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Get 500 random cities and random distances from the equator

# %%
# Getting lat/lng values for finding cities

# Set Lat & Lng Zones to randomly pick geo coordinates
lat_zone = np.arange(-90,90,15)
lng_zone = np.arange(-180,180,15)


# Creating df for geo coordinates
locations_df = pd.DataFrame()

locations_df["Lat"] = ""
locations_df["Lng"] = ""

# From each zone, randomly pick 50 unique coordinates and adding to the dataframe.
for x in lat_zone:
    for y in lng_zone:
        x_values = list(np.arange(x,x+15,0.01))
        y_values = list(np.arange(y,y+15,0.01))
        latitude = random.sample(x_values,50)
        longitude = random.sample(y_values,50)
        lat_samples = [(x+dec_lat) for dec_lat in latitude]
        lng_samples = [y+dec_lng for dec_lng in longitude]
        locations_df = locations_df.append(pd.DataFrame.from_dict({"Lat":lat_samples,
                                       "Lng":lng_samples}))
locations_df = locations_df.reset_index(drop=True)
locations_df.shape
# Out:
# (14400, 2)

# %%
# Using citipy to get nearest city to location coordinates

locations_df["Closest City"] = ""
locations_df["Country Code"] = ""
for index,row in locations_df.iterrows():
    city = citipy.nearest_city(row["Lat"],row["Lng"])
    locations_df.set_value(index,"Closest City",city.city_name)
    locations_df.set_value(index,"Country Code",city.country_code)
locations_df.head()
# Out:
#       Lat     Lng Closest City Country Code
# 0 -178.40 -353.11        vaini           to
# 1 -172.40 -351.03        vaini           to
# 2 -167.35 -355.29        vaini           to
# 3 -177.47 -347.29        vaini           to
# 4 -172.12 -345.29        vaini           to

# %%
# Deleting random coordinates that do not match city coordinates

cities_df = locations_df.drop(['Lat', 'Lng'],axis=1)

# Dropping and duplicate cities
cities_df = cities_df.drop_duplicates()

cities_df.shape
# Out:
# (874, 2)

# %% [markdown]
# # Don't forget to change sample size to 500 when done

# %%
# Getting 500 random cities for the remaining list
random_cities = cities_df.sample(500)
random_cities = random_cities.reset_index(drop=True)
random_cities.head()
# Out:
#       Closest City Country Code
# 0         cananeia           br
# 1          camacha           pt
# 2  bambous virieux           mu
# 3          muborak           uz
# 4            zabol           ir

# %% [markdown]
# # Get weather data for the 500 random cities selected above

# %%
# Get current weather to see the JSON format
settings = {"units": "metric", "appid": api_key}
current_weather_clt = owm.get_current("Charlotte", **settings)
print(f"{json.dumps(current_weather_clt, indent=4)}")
# Out:
# {
#     "coord": {
#         "lon": -80.84,
#         "lat": 35.23
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 10.01,
#         "pressure": 1025,
#         "humidity": 42,
#         "temp_min": 8,
#         "temp_max": 11
#     },
#     "visibility": 16093,
#     "wind": {
#         "speed": 3.6,
#         "deg": 70
#     },
#     "clouds": {
#         "all": 1
#     },
#     "dt": 1522022100,
#     "sys": {
#         "type": 1,
#         "id": 1797,
#         "message": 0.0095,
#         "country": "US",
#         "sunrise": 1522063108,
#         "sunset": 1522107599
#     },
#     "id": 4460243,
#     "name": "Charlotte",
#     "cod": 200
# }

# %%
# Setting up values for OpenWeatherMap API calls
base_url = "http://api.openweathermap.org/data/2.5/weather"

params = { "appid" :api_key,"units":"metric" }

# %%
# Loop through to get Lat, Lng, Temp, Wind Speed, Humidity, and Cloudienss for each random city
# and append to random_cities

# I figured out how to hide my key
def encrypt_key(input_url):
    return input_url[0:53]+"<NoSeeMyKey>"+input_url[85:]

for index,row in random_cities.iterrows():
    params["q"] =f'{row["Closest City"]},{row["Country Code"]}'
    print(f"Processing Record {index+1} for: {params['q']}")
    city_weather = requests.get(base_url,params)
    print(encrypt_key(city_weather.url))
    city_weather  = city_weather.json()
    random_cities.set_value(index,"Latitude",city_weather.get("coord",{}).get("lat"))
    random_cities.set_value(index,"Longitude",city_weather.get("coord",{}).get("lon"))
    random_cities.set_value(index,"Temperature",city_weather.get("main",{}).get("temp_max"))
    random_cities.set_value(index,"Wind Speed",city_weather.get("wind",{}).get("speed"))
    random_cities.set_value(index,"Humidity",city_weather.get("main",{}).get("humidity"))
    random_cities.set_value(index,"Cloudiness",city_weather.get("clouds",{}).get("all"))
# Out:
# Processing Record 1 for: cananeia,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=cananeia%2Cbr
# Processing Record 2 for: camacha,pt
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=camacha%2Cpt
# Processing Record 3 for: bambous virieux,mu
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bambous+virieux%2Cmu
# Processing Record 4 for: muborak,uz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=muborak%2Cuz
# Processing Record 5 for: zabol,ir
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=zabol%2Cir
# Processing Record 6 for: sovetskiy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sovetskiy%2Cru
# Processing Record 7 for: vigia del fuerte,co
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=vigia+del+fuerte%2Cco
# Processing Record 8 for: lagos,ng
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=lagos%2Cng
# Processing Record 9 for: kavaratti,in
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kavaratti%2Cin
# Processing Record 10 for: sangar,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sangar%2Cru
# Processing Record 11 for: huanren,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=huanren%2Ccn
# Processing Record 12 for: caravelas,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=caravelas%2Cbr
# Processing Record 13 for: kruisfontein,za
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kruisfontein%2Cza
# Processing Record 14 for: jijiga,et
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=jijiga%2Cet
# Processing Record 15 for: muli,mv
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=muli%2Cmv
# Processing Record 16 for: yenagoa,ng
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=yenagoa%2Cng
# Processing Record 17 for: teluk nibung,id
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=teluk+nibung%2Cid
# Processing Record 18 for: taolanaro,mg
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=taolanaro%2Cmg
# Processing Record 19 for: filingue,ne
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=filingue%2Cne
# Processing Record 20 for: siverek,tr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=siverek%2Ctr
# Processing Record 21 for: lchashen,am
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=lchashen%2Cam
# Processing Record 22 for: leghorn,it
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=leghorn%2Cit
# Processing Record 23 for: jinka,et
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=jinka%2Cet
# Processing Record 24 for: neiafu,to
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=neiafu%2Cto
# Processing Record 25 for: rio verde de mato grosso,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=rio+verde+de+mato+grosso%2Cbr
# Processing Record 26 for: san pedro de ycuamandiyu,py
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=san+pedro+de+ycuamandiyu%2Cpy
# Processing Record 27 for: fort collins,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=fort+collins%2Cus
# Processing Record 28 for: olafsvik,is
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=olafsvik%2Cis
# Processing Record 29 for: baghdad,iq
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=baghdad%2Ciq
# Processing Record 30 for: lovozero,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=lovozero%2Cru
# Processing Record 31 for: meyungs,pw
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=meyungs%2Cpw
# Processing Record 32 for: bitung,id
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bitung%2Cid
# Processing Record 33 for: meiganga,cm
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=meiganga%2Ccm
# Processing Record 34 for: duz,tn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=duz%2Ctn
# Processing Record 35 for: huarmey,pe
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=huarmey%2Cpe
# Processing Record 36 for: lar gerd,af
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=lar+gerd%2Caf
# Processing Record 37 for: muravlenko,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=muravlenko%2Cru
# Processing Record 38 for: antofagasta,cl
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=antofagasta%2Ccl
# Processing Record 39 for: bertoua,cm
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bertoua%2Ccm
# Processing Record 40 for: mahebourg,mu
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=mahebourg%2Cmu
# Processing Record 41 for: verkhoyansk,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=verkhoyansk%2Cru
# Processing Record 42 for: hamburg,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=hamburg%2Cus
# Processing Record 43 for: povenets,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=povenets%2Cru
# Processing Record 44 for: hobart,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=hobart%2Cau
# Processing Record 45 for: thinadhoo,mv
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=thinadhoo%2Cmv
# Processing Record 46 for: felanitx,es
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=felanitx%2Ces
# Processing Record 47 for: suba,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=suba%2Cph
# Processing Record 48 for: atuona,pf
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=atuona%2Cpf
# Processing Record 49 for: sisimiut,gl
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sisimiut%2Cgl
# Processing Record 50 for: tuscaloosa,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=tuscaloosa%2Cus
# Processing Record 51 for: along,in
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=along%2Cin
# Processing Record 52 for: puerto suarez,bo
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=puerto+suarez%2Cbo
# Processing Record 53 for: sivas,tr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sivas%2Ctr
# Processing Record 54 for: andenes,no
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=andenes%2Cno
# Processing Record 55 for: san isidro,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=san+isidro%2Cph
# Processing Record 56 for: dapa,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=dapa%2Cph
# Processing Record 57 for: garissa,ke
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=garissa%2Cke
# Processing Record 58 for: pangody,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=pangody%2Cru
# Processing Record 59 for: broome,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=broome%2Cau
# Processing Record 60 for: beloha,mg
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=beloha%2Cmg
# Processing Record 61 for: belushya guba,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=belushya+guba%2Cru
# Processing Record 62 for: tignere,cm
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=tignere%2Ccm
# Processing Record 63 for: orgun,af
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=orgun%2Caf
# Processing Record 64 for: hilo,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=hilo%2Cus
# Processing Record 65 for: aklavik,ca
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=aklavik%2Cca
# Processing Record 66 for: bayburt,tr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bayburt%2Ctr
# Processing Record 67 for: charsadda,pk
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=charsadda%2Cpk
# Processing Record 68 for: haines junction,ca
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=haines+junction%2Cca
# Processing Record 69 for: miranda,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=miranda%2Cbr
# Processing Record 70 for: nurota,uz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=nurota%2Cuz
# Processing Record 71 for: nizhneyansk,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=nizhneyansk%2Cru
# Processing Record 72 for: muzhi,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=muzhi%2Cru
# Processing Record 73 for: barentsburg,sj
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=barentsburg%2Csj
# Processing Record 74 for: damascus,sy
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=damascus%2Csy
# Processing Record 75 for: assomada,cv
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=assomada%2Ccv
# Processing Record 76 for: sulangan,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sulangan%2Cph
# Processing Record 77 for: caarapo,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=caarapo%2Cbr
# Processing Record 78 for: maniitsoq,gl
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=maniitsoq%2Cgl
# Processing Record 79 for: lubango,ao
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=lubango%2Cao
# Processing Record 80 for: kabanjahe,id
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kabanjahe%2Cid
# Processing Record 81 for: nacozari,mx
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=nacozari%2Cmx
# Processing Record 82 for: apiai,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=apiai%2Cbr
# Processing Record 83 for: banda aceh,id
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=banda+aceh%2Cid
# Processing Record 84 for: vestmannaeyjar,is
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=vestmannaeyjar%2Cis
# Processing Record 85 for: pantai remis,my
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=pantai+remis%2Cmy
# Processing Record 86 for: afmadu,so
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=afmadu%2Cso
# Processing Record 87 for: kobayashi,jp
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kobayashi%2Cjp
# Processing Record 88 for: voh,nc
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=voh%2Cnc
# Processing Record 89 for: progreso,mx
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=progreso%2Cmx
# Processing Record 90 for: dzhusaly,kz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=dzhusaly%2Ckz
# Processing Record 91 for: nicoya,cr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=nicoya%2Ccr
# Processing Record 92 for: cotonou,bj
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=cotonou%2Cbj
# Processing Record 93 for: camana,pe
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=camana%2Cpe
# Processing Record 94 for: torbay,ca
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=torbay%2Cca
# Processing Record 95 for: maxixe,mz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=maxixe%2Cmz
# Processing Record 96 for: orange cove,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=orange+cove%2Cus
# Processing Record 97 for: miandrivazo,mg
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=miandrivazo%2Cmg
# Processing Record 98 for: fukuma,jp
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=fukuma%2Cjp
# Processing Record 99 for: weihai,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=weihai%2Ccn
# Processing Record 100 for: avarua,ck
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=avarua%2Cck
# Processing Record 101 for: hit,iq
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=hit%2Ciq
# Processing Record 102 for: khao yoi,th
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=khao+yoi%2Cth
# Processing Record 103 for: beroroha,mg
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=beroroha%2Cmg
# Processing Record 104 for: verkhnevilyuysk,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=verkhnevilyuysk%2Cru
# Processing Record 105 for: khatanga,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=khatanga%2Cru
# Processing Record 106 for: nuoro,it
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=nuoro%2Cit
# Processing Record 107 for: birin,dz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=birin%2Cdz
# Processing Record 108 for: ankazoabo,mg
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ankazoabo%2Cmg
# Processing Record 109 for: roald,no
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=roald%2Cno
# Processing Record 110 for: ugoofaaru,mv
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ugoofaaru%2Cmv
# Processing Record 111 for: anloga,gh
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=anloga%2Cgh
# Processing Record 112 for: marcona,pe
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=marcona%2Cpe
# Processing Record 113 for: tabarqah,tn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=tabarqah%2Ctn
# Processing Record 114 for: linjiang,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=linjiang%2Ccn
# Processing Record 115 for: chegutu,zw
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=chegutu%2Czw
# Processing Record 116 for: uruguaiana,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=uruguaiana%2Cbr
# Processing Record 117 for: dakar,sn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=dakar%2Csn
# Processing Record 118 for: egvekinot,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=egvekinot%2Cru
# Processing Record 119 for: dalinghe,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=dalinghe%2Ccn
# Processing Record 120 for: asau,tv
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=asau%2Ctv
# Processing Record 121 for: richards bay,za
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=richards+bay%2Cza
# Processing Record 122 for: maragogi,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=maragogi%2Cbr
# Processing Record 123 for: roura,gf
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=roura%2Cgf
# Processing Record 124 for: green river,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=green+river%2Cus
# Processing Record 125 for: abu kamal,sy
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=abu+kamal%2Csy
# Processing Record 126 for: angoche,mz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=angoche%2Cmz
# Processing Record 127 for: belen,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=belen%2Cus
# Processing Record 128 for: santa cruz de la palma,es
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=santa+cruz+de+la+palma%2Ces
# Processing Record 129 for: yucaipa,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=yucaipa%2Cus
# Processing Record 130 for: shkotovo-22,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=shkotovo-22%2Cru
# Processing Record 131 for: thompson,ca
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=thompson%2Cca
# Processing Record 132 for: muisne,ec
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=muisne%2Cec
# Processing Record 133 for: warqla,dz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=warqla%2Cdz
# Processing Record 134 for: teahupoo,pf
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=teahupoo%2Cpf
# Processing Record 135 for: namibe,ao
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=namibe%2Cao
# Processing Record 136 for: turayf,sa
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=turayf%2Csa
# Processing Record 137 for: bani walid,ly
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bani+walid%2Cly
# Processing Record 138 for: coquimbo,cl
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=coquimbo%2Ccl
# Processing Record 139 for: kamenskoye,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kamenskoye%2Cru
# Processing Record 140 for: winchester,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=winchester%2Cus
# Processing Record 141 for: hay river,ca
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=hay+river%2Cca
# Processing Record 142 for: pozo colorado,py
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=pozo+colorado%2Cpy
# Processing Record 143 for: urumqi,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=urumqi%2Ccn
# Processing Record 144 for: yumen,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=yumen%2Ccn
# Processing Record 145 for: imbituba,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=imbituba%2Cbr
# Processing Record 146 for: pinan,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=pinan%2Cph
# Processing Record 147 for: kankakee,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kankakee%2Cus
# Processing Record 148 for: palmas,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=palmas%2Cbr
# Processing Record 149 for: teya,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=teya%2Cru
# Processing Record 150 for: mackay,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=mackay%2Cau
# Processing Record 151 for: grindavik,is
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=grindavik%2Cis
# Processing Record 152 for: viedma,ar
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=viedma%2Car
# Processing Record 153 for: bud,no
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bud%2Cno
# Processing Record 154 for: yar-sale,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=yar-sale%2Cru
# Processing Record 155 for: tabialan,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=tabialan%2Cph
# Processing Record 156 for: kununurra,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kununurra%2Cau
# Processing Record 157 for: opuwo,na
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=opuwo%2Cna
# Processing Record 158 for: toowoomba,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=toowoomba%2Cau
# Processing Record 159 for: lasa,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=lasa%2Ccn
# Processing Record 160 for: cotacachi,ec
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=cotacachi%2Cec
# Processing Record 161 for: bethel,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bethel%2Cus
# Processing Record 162 for: kulhudhuffushi,mv
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kulhudhuffushi%2Cmv
# Processing Record 163 for: camopi,gf
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=camopi%2Cgf
# Processing Record 164 for: jiuquan,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=jiuquan%2Ccn
# Processing Record 165 for: vila velha,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=vila+velha%2Cbr
# Processing Record 166 for: acapulco,mx
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=acapulco%2Cmx
# Processing Record 167 for: tuggurt,dz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=tuggurt%2Cdz
# Processing Record 168 for: albany,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=albany%2Cau
# Processing Record 169 for: singapore,sg
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=singapore%2Csg
# Processing Record 170 for: washington,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=washington%2Cus
# Processing Record 171 for: vilyuysk,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=vilyuysk%2Cru
# Processing Record 172 for: attawapiskat,ca
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=attawapiskat%2Cca
# Processing Record 173 for: wingham,ca
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=wingham%2Cca
# Processing Record 174 for: pasir gudang,my
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=pasir+gudang%2Cmy
# Processing Record 175 for: fare,pf
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=fare%2Cpf
# Processing Record 176 for: bahir dar,et
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bahir+dar%2Cet
# Processing Record 177 for: mardin,tr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=mardin%2Ctr
# Processing Record 178 for: mocambique,mz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=mocambique%2Cmz
# Processing Record 179 for: jackson,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=jackson%2Cus
# Processing Record 180 for: iqaluit,ca
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=iqaluit%2Cca
# Processing Record 181 for: kahta,tr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kahta%2Ctr
# Processing Record 182 for: nichinan,jp
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=nichinan%2Cjp
# Processing Record 183 for: hargeysa,so
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=hargeysa%2Cso
# Processing Record 184 for: espanola,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=espanola%2Cus
# Processing Record 185 for: diofior,sn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=diofior%2Csn
# Processing Record 186 for: sorland,no
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sorland%2Cno
# Processing Record 187 for: silver city,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=silver+city%2Cus
# Processing Record 188 for: dukat,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=dukat%2Cru
# Processing Record 189 for: rabo de peixe,pt
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=rabo+de+peixe%2Cpt
# Processing Record 190 for: san miguel,pa
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=san+miguel%2Cpa
# Processing Record 191 for: cherskiy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=cherskiy%2Cru
# Processing Record 192 for: hovd,mn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=hovd%2Cmn
# Processing Record 193 for: margate,za
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=margate%2Cza
# Processing Record 194 for: quelimane,mz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=quelimane%2Cmz
# Processing Record 195 for: dalton,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=dalton%2Cus
# Processing Record 196 for: jaque,pa
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=jaque%2Cpa
# Processing Record 197 for: puerto el triunfo,sv
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=puerto+el+triunfo%2Csv
# Processing Record 198 for: kavieng,pg
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kavieng%2Cpg
# Processing Record 199 for: serramanna,it
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=serramanna%2Cit
# Processing Record 200 for: rungata,ki
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=rungata%2Cki
# Processing Record 201 for: laguna de perlas,ni
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=laguna+de+perlas%2Cni
# Processing Record 202 for: nefteyugansk,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=nefteyugansk%2Cru
# Processing Record 203 for: mudu,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=mudu%2Ccn
# Processing Record 204 for: acari,pe
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=acari%2Cpe
# Processing Record 205 for: kysyl-syr,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kysyl-syr%2Cru
# Processing Record 206 for: goure,ne
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=goure%2Cne
# Processing Record 207 for: santiago,pe
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=santiago%2Cpe
# Processing Record 208 for: gornopravdinsk,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=gornopravdinsk%2Cru
# Processing Record 209 for: uvat,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=uvat%2Cru
# Processing Record 210 for: betare oya,cm
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=betare+oya%2Ccm
# Processing Record 211 for: masvingo,zw
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=masvingo%2Czw
# Processing Record 212 for: kumba,cm
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kumba%2Ccm
# Processing Record 213 for: waipawa,nz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=waipawa%2Cnz
# Processing Record 214 for: yatou,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=yatou%2Ccn
# Processing Record 215 for: verkhniy kurkuzhin,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=verkhniy+kurkuzhin%2Cru
# Processing Record 216 for: sai buri,th
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sai+buri%2Cth
# Processing Record 217 for: kamenka,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kamenka%2Cru
# Processing Record 218 for: los llanos de aridane,es
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=los+llanos+de+aridane%2Ces
# Processing Record 219 for: bedford,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bedford%2Cus
# Processing Record 220 for: sinop,tr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sinop%2Ctr
# Processing Record 221 for: skalistyy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=skalistyy%2Cru
# Processing Record 222 for: berdigestyakh,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=berdigestyakh%2Cru
# Processing Record 223 for: loukhi,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=loukhi%2Cru
# Processing Record 224 for: longyearbyen,sj
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=longyearbyen%2Csj
# Processing Record 225 for: nikki,bj
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=nikki%2Cbj
# Processing Record 226 for: sao sebastiao,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sao+sebastiao%2Cbr
# Processing Record 227 for: battle creek,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=battle+creek%2Cus
# Processing Record 228 for: bichena,et
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bichena%2Cet
# Processing Record 229 for: columbus,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=columbus%2Cus
# Processing Record 230 for: rikitea,pf
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=rikitea%2Cpf
# Processing Record 231 for: don sak,th
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=don+sak%2Cth
# Processing Record 232 for: saint-pierre,pm
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=saint-pierre%2Cpm
# Processing Record 233 for: pirapozinho,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=pirapozinho%2Cbr
# Processing Record 234 for: hofn,is
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=hofn%2Cis
# Processing Record 235 for: savinskiy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=savinskiy%2Cru
# Processing Record 236 for: wisconsin rapids,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=wisconsin+rapids%2Cus
# Processing Record 237 for: pevek,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=pevek%2Cru
# Processing Record 238 for: balad,iq
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=balad%2Ciq
# Processing Record 239 for: lalibela,et
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=lalibela%2Cet
# Processing Record 240 for: aradippou,cy
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=aradippou%2Ccy
# Processing Record 241 for: eskasem,af
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=eskasem%2Caf
# Processing Record 242 for: saint george,bm
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=saint+george%2Cbm
# Processing Record 243 for: sao joao da barra,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sao+joao+da+barra%2Cbr
# Processing Record 244 for: oussouye,sn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=oussouye%2Csn
# Processing Record 245 for: pilar,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=pilar%2Cph
# Processing Record 246 for: kars,tr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kars%2Ctr
# Processing Record 247 for: presidencia roque saenz pena,ar
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=presidencia+roque+saenz+pena%2Car
# Processing Record 248 for: trang,th
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=trang%2Cth
# Processing Record 249 for: keta,gh
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=keta%2Cgh
# Processing Record 250 for: ho,gh
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ho%2Cgh
# Processing Record 251 for: sistranda,no
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sistranda%2Cno
# Processing Record 252 for: altoona,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=altoona%2Cus
# Processing Record 253 for: tiksi,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=tiksi%2Cru
# Processing Record 254 for: kannangad,in
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kannangad%2Cin
# Processing Record 255 for: san jeronimo,mx
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=san+jeronimo%2Cmx
# Processing Record 256 for: sitka,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sitka%2Cus
# Processing Record 257 for: totness,sr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=totness%2Csr
# Processing Record 258 for: hervey bay,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=hervey+bay%2Cau
# Processing Record 259 for: loding,no
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=loding%2Cno
# Processing Record 260 for: dunedin,nz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=dunedin%2Cnz
# Processing Record 261 for: russell,nz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=russell%2Cnz
# Processing Record 262 for: vanavara,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=vanavara%2Cru
# Processing Record 263 for: oriximina,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=oriximina%2Cbr
# Processing Record 264 for: port lincoln,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=port+lincoln%2Cau
# Processing Record 265 for: abonnema,ng
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=abonnema%2Cng
# Processing Record 266 for: new norfolk,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=new+norfolk%2Cau
# Processing Record 267 for: port blair,in
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=port+blair%2Cin
# Processing Record 268 for: la palma,pa
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=la+palma%2Cpa
# Processing Record 269 for: tasbuget,kz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=tasbuget%2Ckz
# Processing Record 270 for: burica,pa
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=burica%2Cpa
# Processing Record 271 for: karamken,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=karamken%2Cru
# Processing Record 272 for: buala,sb
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=buala%2Csb
# Processing Record 273 for: marapanim,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=marapanim%2Cbr
# Processing Record 274 for: caraga,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=caraga%2Cph
# Processing Record 275 for: sakakah,sa
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sakakah%2Csa
# Processing Record 276 for: bhatkal,in
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bhatkal%2Cin
# Processing Record 277 for: mao,td
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=mao%2Ctd
# Processing Record 278 for: bongaree,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bongaree%2Cau
# Processing Record 279 for: talas,kg
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=talas%2Ckg
# Processing Record 280 for: paamiut,gl
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=paamiut%2Cgl
# Processing Record 281 for: zinder,ne
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=zinder%2Cne
# Processing Record 282 for: male,mv
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=male%2Cmv
# Processing Record 283 for: tongliao,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=tongliao%2Ccn
# Processing Record 284 for: xining,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=xining%2Ccn
# Processing Record 285 for: lanzhou,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=lanzhou%2Ccn
# Processing Record 286 for: ca mau,vn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ca+mau%2Cvn
# Processing Record 287 for: handwara,in
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=handwara%2Cin
# Processing Record 288 for: san matias,bo
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=san+matias%2Cbo
# Processing Record 289 for: palabuhanratu,id
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=palabuhanratu%2Cid
# Processing Record 290 for: palombara sabina,it
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=palombara+sabina%2Cit
# Processing Record 291 for: zapolyarnyy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=zapolyarnyy%2Cru
# Processing Record 292 for: gore,et
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=gore%2Cet
# Processing Record 293 for: hazorasp,uz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=hazorasp%2Cuz
# Processing Record 294 for: bako,et
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bako%2Cet
# Processing Record 295 for: dondo,mz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=dondo%2Cmz
# Processing Record 296 for: punta arenas,cl
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=punta+arenas%2Ccl
# Processing Record 297 for: churapcha,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=churapcha%2Cru
# Processing Record 298 for: yei,sd
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=yei%2Csd
# Processing Record 299 for: college,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=college%2Cus
# Processing Record 300 for: olga,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=olga%2Cru
# Processing Record 301 for: rawson,ar
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=rawson%2Car
# Processing Record 302 for: mount gambier,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=mount+gambier%2Cau
# Processing Record 303 for: luangwa,zm
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=luangwa%2Czm
# Processing Record 304 for: carbondale,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=carbondale%2Cus
# Processing Record 305 for: doong,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=doong%2Cph
# Processing Record 306 for: omsukchan,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=omsukchan%2Cru
# Processing Record 307 for: gambela,et
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=gambela%2Cet
# Processing Record 308 for: cassilandia,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=cassilandia%2Cbr
# Processing Record 309 for: pahrump,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=pahrump%2Cus
# Processing Record 310 for: bengkulu,id
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bengkulu%2Cid
# Processing Record 311 for: chapada dos guimaraes,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=chapada+dos+guimaraes%2Cbr
# Processing Record 312 for: jimeta,ng
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=jimeta%2Cng
# Processing Record 313 for: orbetello,it
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=orbetello%2Cit
# Processing Record 314 for: sundumbili,za
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sundumbili%2Cza
# Processing Record 315 for: manokwari,id
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=manokwari%2Cid
# Processing Record 316 for: hualmay,pe
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=hualmay%2Cpe
# Processing Record 317 for: manzanillo,mx
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=manzanillo%2Cmx
# Processing Record 318 for: nedjo,et
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=nedjo%2Cet
# Processing Record 319 for: sao filipe,cv
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sao+filipe%2Ccv
# Processing Record 320 for: jamestown,sh
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=jamestown%2Csh
# Processing Record 321 for: malatya,tr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=malatya%2Ctr
# Processing Record 322 for: tivaouane,sn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=tivaouane%2Csn
# Processing Record 323 for: kodinsk,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kodinsk%2Cru
# Processing Record 324 for: talaya,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=talaya%2Cru
# Processing Record 325 for: rockhampton,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=rockhampton%2Cau
# Processing Record 326 for: mocuba,mz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=mocuba%2Cmz
# Processing Record 327 for: fernley,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=fernley%2Cus
# Processing Record 328 for: gisborne,nz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=gisborne%2Cnz
# Processing Record 329 for: biograd na moru,hr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=biograd+na+moru%2Chr
# Processing Record 330 for: san estanislao,py
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=san+estanislao%2Cpy
# Processing Record 331 for: yulara,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=yulara%2Cau
# Processing Record 332 for: talkha,eg
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=talkha%2Ceg
# Processing Record 333 for: kangaatsiaq,gl
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kangaatsiaq%2Cgl
# Processing Record 334 for: iracoubo,gf
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=iracoubo%2Cgf
# Processing Record 335 for: west wendover,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=west+wendover%2Cus
# Processing Record 336 for: severo-kurilsk,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=severo-kurilsk%2Cru
# Processing Record 337 for: toyooka,jp
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=toyooka%2Cjp
# Processing Record 338 for: santa marinella,it
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=santa+marinella%2Cit
# Processing Record 339 for: briancon,fr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=briancon%2Cfr
# Processing Record 340 for: san jorge,ni
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=san+jorge%2Cni
# Processing Record 341 for: inverell,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=inverell%2Cau
# Processing Record 342 for: cheuskiny,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=cheuskiny%2Cru
# Processing Record 343 for: juegang,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=juegang%2Ccn
# Processing Record 344 for: grafton,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=grafton%2Cau
# Processing Record 345 for: port-de-bouc,fr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=port-de-bouc%2Cfr
# Processing Record 346 for: aksarka,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=aksarka%2Cru
# Processing Record 347 for: alizai,pk
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=alizai%2Cpk
# Processing Record 348 for: kapaa,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kapaa%2Cus
# Processing Record 349 for: sabang,id
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sabang%2Cid
# Processing Record 350 for: hafizabad,pk
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=hafizabad%2Cpk
# Processing Record 351 for: hithadhoo,mv
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=hithadhoo%2Cmv
# Processing Record 352 for: hattiesburg,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=hattiesburg%2Cus
# Processing Record 353 for: morondava,mg
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=morondava%2Cmg
# Processing Record 354 for: qasigiannguit,gl
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=qasigiannguit%2Cgl
# Processing Record 355 for: coahuayana,mx
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=coahuayana%2Cmx
# Processing Record 356 for: honavar,in
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=honavar%2Cin
# Processing Record 357 for: cayenne,gf
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=cayenne%2Cgf
# Processing Record 358 for: dinsor,so
# ...
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bitlis%2Ctr
# Processing Record 383 for: magdalena,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=magdalena%2Cph
# Processing Record 384 for: amapa,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=amapa%2Cbr
# Processing Record 385 for: elizabeth city,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=elizabeth+city%2Cus
# Processing Record 386 for: virginia beach,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=virginia+beach%2Cus
# Processing Record 387 for: qunduz,af
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=qunduz%2Caf
# Processing Record 388 for: winslow,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=winslow%2Cus
# Processing Record 389 for: twentynine palms,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=twentynine+palms%2Cus
# Processing Record 390 for: kloulklubed,pw
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kloulklubed%2Cpw
# Processing Record 391 for: goya,ar
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=goya%2Car
# Processing Record 392 for: northam,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=northam%2Cau
# Processing Record 393 for: songjianghe,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=songjianghe%2Ccn
# Processing Record 394 for: laurinburg,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=laurinburg%2Cus
# Processing Record 395 for: chaman,pk
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=chaman%2Cpk
# Processing Record 396 for: tazmalt,dz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=tazmalt%2Cdz
# Processing Record 397 for: chau doc,vn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=chau+doc%2Cvn
# Processing Record 398 for: san andres,co
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=san+andres%2Cco
# Processing Record 399 for: unai,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=unai%2Cbr
# Processing Record 400 for: pundaguitan,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=pundaguitan%2Cph
# Processing Record 401 for: bafra,tr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bafra%2Ctr
# Processing Record 402 for: provideniya,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=provideniya%2Cru
# Processing Record 403 for: zhangye,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=zhangye%2Ccn
# Processing Record 404 for: tigzirt,dz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=tigzirt%2Cdz
# Processing Record 405 for: ossora,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ossora%2Cru
# Processing Record 406 for: murgab,tm
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=murgab%2Ctm
# Processing Record 407 for: makakilo city,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=makakilo+city%2Cus
# Processing Record 408 for: anori,co
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=anori%2Cco
# Processing Record 409 for: chkalovskoye,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=chkalovskoye%2Cru
# Processing Record 410 for: goksun,tr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=goksun%2Ctr
# Processing Record 411 for: korem,et
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=korem%2Cet
# Processing Record 412 for: busselton,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=busselton%2Cau
# Processing Record 413 for: ardahan,tr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ardahan%2Ctr
# Processing Record 414 for: sahrak,af
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sahrak%2Caf
# Processing Record 415 for: carson city,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=carson+city%2Cus
# Processing Record 416 for: narsaq,gl
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=narsaq%2Cgl
# Processing Record 417 for: ontario,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ontario%2Cus
# Processing Record 418 for: labutta,mm
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=labutta%2Cmm
# Processing Record 419 for: turukhansk,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=turukhansk%2Cru
# Processing Record 420 for: verkhnyaya inta,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=verkhnyaya+inta%2Cru
# Processing Record 421 for: zonguldak,tr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=zonguldak%2Ctr
# Processing Record 422 for: riverton,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=riverton%2Cus
# Processing Record 423 for: yeppoon,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=yeppoon%2Cau
# Processing Record 424 for: srednekolymsk,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=srednekolymsk%2Cru
# Processing Record 425 for: show low,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=show+low%2Cus
# Processing Record 426 for: east london,za
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=east+london%2Cza
# Processing Record 427 for: lambare,py
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=lambare%2Cpy
# Processing Record 428 for: kazalinsk,kz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kazalinsk%2Ckz
# Processing Record 429 for: alenquer,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=alenquer%2Cbr
# Processing Record 430 for: abu jubayhah,sd
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=abu+jubayhah%2Csd
# Processing Record 431 for: bowen,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bowen%2Cau
# Processing Record 432 for: bubaque,gw
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bubaque%2Cgw
# Processing Record 433 for: diffa,ne
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=diffa%2Cne
# Processing Record 434 for: nadym,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=nadym%2Cru
# Processing Record 435 for: tottori,jp
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=tottori%2Cjp
# Processing Record 436 for: ranong,th
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ranong%2Cth
# Processing Record 437 for: mergui,mm
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=mergui%2Cmm
# Processing Record 438 for: barretos,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=barretos%2Cbr
# Processing Record 439 for: saint-philippe,re
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=saint-philippe%2Cre
# Processing Record 440 for: robe,et
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=robe%2Cet
# Processing Record 441 for: ruatoria,nz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ruatoria%2Cnz
# Processing Record 442 for: marquetalia,co
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=marquetalia%2Cco
# Processing Record 443 for: salalah,om
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=salalah%2Com
# Processing Record 444 for: chiredzi,zw
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=chiredzi%2Czw
# Processing Record 445 for: alakurtti,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=alakurtti%2Cru
# Processing Record 446 for: christchurch,nz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=christchurch%2Cnz
# Processing Record 447 for: kaka,tm
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kaka%2Ctm
# Processing Record 448 for: paka,my
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=paka%2Cmy
# Processing Record 449 for: inhambane,mz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=inhambane%2Cmz
# Processing Record 450 for: raudeberg,no
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=raudeberg%2Cno
# Processing Record 451 for: toliary,mg
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=toliary%2Cmg
# Processing Record 452 for: bonthe,sl
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bonthe%2Csl
# Processing Record 453 for: marienburg,sr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=marienburg%2Csr
# Processing Record 454 for: gladstone,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=gladstone%2Cau
# Processing Record 455 for: agirish,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=agirish%2Cru
# Processing Record 456 for: talnakh,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=talnakh%2Cru
# Processing Record 457 for: hasaki,jp
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=hasaki%2Cjp
# Processing Record 458 for: souillac,mu
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=souillac%2Cmu
# Processing Record 459 for: tatawin,tn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=tatawin%2Ctn
# Processing Record 460 for: victoria point,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=victoria+point%2Cau
# Processing Record 461 for: pisco,pe
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=pisco%2Cpe
# Processing Record 462 for: beringovskiy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=beringovskiy%2Cru
# Processing Record 463 for: ribeira grande,pt
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ribeira+grande%2Cpt
# Processing Record 464 for: redmond,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=redmond%2Cus
# Processing Record 465 for: husavik,is
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=husavik%2Cis
# Processing Record 466 for: lodwar,ke
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=lodwar%2Cke
# Processing Record 467 for: naftah,tn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=naftah%2Ctn
# Processing Record 468 for: vila franca do campo,pt
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=vila+franca+do+campo%2Cpt
# Processing Record 469 for: ixtapa,mx
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ixtapa%2Cmx
# Processing Record 470 for: bay roberts,ca
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bay+roberts%2Cca
# Processing Record 471 for: hihifo,to
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=hihifo%2Cto
# Processing Record 472 for: marneuli,ge
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=marneuli%2Cge
# Processing Record 473 for: bassila,bj
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bassila%2Cbj
# Processing Record 474 for: socorro,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=socorro%2Cus
# Processing Record 475 for: bairiki,ki
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bairiki%2Cki
# Processing Record 476 for: bundaberg,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bundaberg%2Cau
# Processing Record 477 for: puerto colombia,co
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=puerto+colombia%2Cco
# Processing Record 478 for: mutoko,zw
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=mutoko%2Czw
# Processing Record 479 for: yaan,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=yaan%2Ccn
# Processing Record 480 for: charleston,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=charleston%2Cus
# Processing Record 481 for: puerto quijarro,bo
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=puerto+quijarro%2Cbo
# Processing Record 482 for: malayal,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=malayal%2Cph
# Processing Record 483 for: weston,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=weston%2Cus
# Processing Record 484 for: vila do maio,cv
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=vila+do+maio%2Ccv
# Processing Record 485 for: taltal,cl
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=taltal%2Ccl
# Processing Record 486 for: oistins,bb
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=oistins%2Cbb
# Processing Record 487 for: praia da vitoria,pt
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=praia+da+vitoria%2Cpt
# Processing Record 488 for: phangnga,th
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=phangnga%2Cth
# Processing Record 489 for: ninotsminda,ge
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ninotsminda%2Cge
# Processing Record 490 for: mutis,co
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=mutis%2Cco
# Processing Record 491 for: lebu,cl
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=lebu%2Ccl
# Processing Record 492 for: necochea,ar
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=necochea%2Car
# Processing Record 493 for: qaanaaq,gl
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=qaanaaq%2Cgl
# Processing Record 494 for: bluff,nz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bluff%2Cnz
# Processing Record 495 for: pobe,bj
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=pobe%2Cbj
# Processing Record 496 for: bartica,gy
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bartica%2Cgy
# Processing Record 497 for: kaitong,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kaitong%2Ccn
# Processing Record 498 for: siniscola,it
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=siniscola%2Cit
# Processing Record 499 for: masallatah,ly
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=masallatah%2Cly
# Processing Record 500 for: eureka,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=eureka%2Cus

# %%
# Drop cities with missing information and create csv file
random_cities = random_cities.dropna()
random_cities.to_csv("city_weather_data.csv")
print(random_cities.shape)
random_cities.head()
# Out:
# (439, 8)
#       Closest City Country Code  Latitude  Longitude  Temperature  Wind Speed  \
# 0         cananeia           br    -25.01     -47.93        27.42        5.25
# 1          camacha           pt     33.08     -16.33        17.00        7.20
# 2  bambous virieux           mu    -20.34      57.76        25.00        2.10
# 3          muborak           uz     39.25      65.15        15.32        1.20
# 4            zabol           ir     31.03      61.49        16.80        4.80
#
#    Humidity  Cloudiness
# 0      91.0        24.0
# 1      72.0        40.0
# 2      83.0        20.0
# 3      74.0        68.0
# 4      83.0         0.0

# %% [markdown]
# # Scatterplots to visualize data for data analysis
#
#
#
#
# # Maximum Temperature versus Latitude

# %%
# Temperature vs Latitude 
random_cities.plot(kind="scatter",x="Latitude",y="Temperature",grid=True,color="blue")
plt.title(" Maximum Temperature (Celcius) versus Latitude")
plt.ylabel("Maximum Temperature (Celcius)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-90,90])
plt.axvline(0, color='black',alpha=0.5)
plt.savefig("Maximum Temperature vs Latitude")
plt.show()

# %% [markdown]
# # Maximum Temperature versus Latitude - Observations
# This is the observation for this chart.
#
#
# # Humidity versus Latitude

# %%
# Humidity vs Latitude 

random_cities.plot(kind="scatter",x="Latitude",y="Humidity",grid=True,color="blue")
plt.title("Humidity versus Latitude")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-90,90])
plt.axvline(0, color='black',alpha=0.5)
plt.savefig("Humidity vs Latitude")
plt.show()

# %% [markdown]
# # Humidity versus Latitude - Observations
# This is the observation for this chart.
#
#
# # Wind Speed versus Latitude

# %%
# Wind Speed vs Latitude
random_cities["Wind Speed"] = pd.to_numeric(random_cities["Wind Speed"])
random_cities.plot(kind="scatter",x="Latitude",y="Wind Speed",grid=True,color="blue")
plt.title("Wind Spead versus Latitude")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-90,90])
plt.axvline(0, color='black',alpha=0.5)
plt.savefig("Wind speed vs Latitude")
plt.show()

# %% [markdown]
# # Wind Speed versus Latitude - Observations
# This is the observation for this chart.
#
#
# # Cloudiness versus Latitude

# %%
# Cloudiness vs Latitude
random_cities["Cloudiness"] = pd.to_numeric(random_cities["Cloudiness"])
random_cities.plot(kind="scatter",x="Latitude",y="Cloudiness",grid=True,color="blue")
plt.title("Cloudiness versus Latitude")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-90,90])
plt.axvline(0, color='black',alpha=0.5)
plt.savefig("Cloudiness vs Latitude")
plt.show()

# %% [markdown]
# # Cloudiness versus Latitude - Observations
# This is the observation for this chart.
