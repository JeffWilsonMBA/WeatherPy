# %% [markdown]
# # What's the weather like as we approach the equator?
#
# Create a Python script to visualize the weather of 500+ cities across the world of varying distance from the equator.
#
# NOTE: This project takes into account the weather inforomation from one day. Each time the code is run it randomizes 500 cities and pulls the current weather data so the results of this code will vary each time it is run.

# %%
# ependencies
import openweathermapy.core as owm
import json
import os
import csv
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import random
import requests
from citipy import citipy
from datetime import datetime as dt

# Get API key
from owm_config import api_key

# Set plot style
plt.style.use("seaborn")

# To hide warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Get 500 random cities and random distances from the equator

# %%
# Getting lat/lng values for finding cities

# Set Lat & Lng Zones to randomly pick geo coordinates
lat_zone = np.arange(-90,90,15)
lng_zone = np.arange(-180,180,15)


# Creating df for geo coordinates
locations_df = pd.DataFrame()

locations_df["Lat"] = ""
locations_df["Lng"] = ""

# From each zone, randomly pick 50 unique coordinates and adding to the dataframe.
for x in lat_zone:
    for y in lng_zone:
        x_values = list(np.arange(x,x+15,0.01))
        y_values = list(np.arange(y,y+15,0.01))
        latitude = random.sample(x_values,75)
        longitude = random.sample(y_values,75)
        lat_samples = [(x+dec_lat) for dec_lat in latitude]
        lng_samples = [y+dec_lng for dec_lng in longitude]
        locations_df = locations_df.append(pd.DataFrame.from_dict({"Lat":lat_samples,
                                       "Lng":lng_samples}))
locations_df = locations_df.reset_index(drop=True)
locations_df.shape
# Out:
# (21600, 2)

# %%
# Using citipy to get nearest city to location coordinates

locations_df["Closest City"] = ""
locations_df["Country Code"] = ""
for index,row in locations_df.iterrows():
    city = citipy.nearest_city(row["Lat"],row["Lng"])
    locations_df.set_value(index,"Closest City",city.city_name)
    locations_df.set_value(index,"Country Code",city.country_code)
locations_df.head()
# Out:
#       Lat     Lng Closest City Country Code
# 0 -168.03 -351.68        vaini           to
# 1 -174.47 -359.58        vaini           to
# 2 -166.06 -355.96        vaini           to
# 3 -176.64 -347.05        vaini           to
# 4 -171.88 -350.50        vaini           to

# %%
# Deleting random coordinates that do not match city coordinates

cities_df = locations_df.drop(['Lat', 'Lng'],axis=1)

# Dropping and duplicate cities
cities_df = cities_df.drop_duplicates()

cities_df.shape
# Out:
# (1115, 2)

# %%
# Getting 500 random cities for the remaining list
random_cities = cities_df.sample(600)
random_cities = random_cities.reset_index(drop=True)
random_cities.head()
# Out:
#   Closest City Country Code
# 0         jand           pk
# 1  san lorenzo           ar
# 2     mosquera           co
# 3        wajid           so
# 4    upernavik           gl

# %% [markdown]
# # Get weather data for the 500 random cities selected above

# %%
# Get current weather to see the JSON format
settings = {"units": "metric", "appid": api_key}
current_weather_clt = owm.get_current("Charlotte", **settings)
print(f"{json.dumps(current_weather_clt, indent=4)}")
# Out:
# {
#     "coord": {
#         "lon": -80.84,
#         "lat": 35.23
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 10.51,
#         "pressure": 1027,
#         "humidity": 71,
#         "temp_min": 9,
#         "temp_max": 12
#     },
#     "visibility": 16093,
#     "wind": {
#         "speed": 3.6,
#         "deg": 180
#     },
#     "clouds": {
#         "all": 90
#     },
#     "dt": 1522187640,
#     "sys": {
#         "type": 1,
#         "id": 1771,
#         "message": 0.1684,
#         "country": "US",
#         "sunrise": 1522149346,
#         "sunset": 1522194092
#     },
#     "id": 4460243,
#     "name": "Charlotte",
#     "cod": 200
# }

# %%
# Setting up values for OpenWeatherMap API calls
base_url = "http://api.openweathermap.org/data/2.5/weather"

params = { "appid" :api_key,"units":"metric" }

# %%
# Loop through to get Lat, Lng, Temp, Wind Speed, Humidity, and Cloudienss for each random city
# and append to random_cities

# I figured out how to hide my key
def hide_key(input_url):
    return input_url[0:53]+"<NoSeeMyKey>"+input_url[85:]

for index,row in random_cities.iterrows():
    params["q"] =f'{row["Closest City"]},{row["Country Code"]}'
    print(f"Processing Record {index+1} for: {params['q']}")
    city_weather = requests.get(base_url,params)
    print(hide_key(city_weather.url))
    city_weather  = city_weather.json()
    random_cities.set_value(index,"Latitude",city_weather.get("coord",{}).get("lat"))
    random_cities.set_value(index,"Longitude",city_weather.get("coord",{}).get("lon"))
    random_cities.set_value(index,"Temperature",city_weather.get("main",{}).get("temp_max"))
    random_cities.set_value(index,"Wind Speed",city_weather.get("wind",{}).get("speed"))
    random_cities.set_value(index,"Humidity",city_weather.get("main",{}).get("humidity"))
    random_cities.set_value(index,"Cloudiness",city_weather.get("clouds",{}).get("all"))
# Out:
# Processing Record 1 for: jand,pk
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=jand%2Cpk
# Processing Record 2 for: san lorenzo,ar
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=san+lorenzo%2Car
# Processing Record 3 for: mosquera,co
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=mosquera%2Cco
# Processing Record 4 for: wajid,so
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=wajid%2Cso
# Processing Record 5 for: upernavik,gl
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=upernavik%2Cgl
# Processing Record 6 for: provideniya,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=provideniya%2Cru
# Processing Record 7 for: nagato,jp
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=nagato%2Cjp
# Processing Record 8 for: price,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=price%2Cus
# Processing Record 9 for: poum,nc
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=poum%2Cnc
# Processing Record 10 for: washington,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=washington%2Cus
# Processing Record 11 for: pitsunda,ge
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=pitsunda%2Cge
# Processing Record 12 for: zmeyskaya,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=zmeyskaya%2Cru
# Processing Record 13 for: ranong,th
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ranong%2Cth
# Processing Record 14 for: hihya,eg
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=hihya%2Ceg
# Processing Record 15 for: severo-yeniseyskiy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=severo-yeniseyskiy%2Cru
# Processing Record 16 for: inhambane,mz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=inhambane%2Cmz
# Processing Record 17 for: durango,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=durango%2Cus
# Processing Record 18 for: vanavara,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=vanavara%2Cru
# Processing Record 19 for: yatou,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=yatou%2Ccn
# Processing Record 20 for: bani walid,ly
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bani+walid%2Cly
# Processing Record 21 for: kango,ga
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kango%2Cga
# Processing Record 22 for: maloshuyka,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=maloshuyka%2Cru
# Processing Record 23 for: storforshei,no
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=storforshei%2Cno
# Processing Record 24 for: warqla,dz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=warqla%2Cdz
# Processing Record 25 for: mayo,ca
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=mayo%2Cca
# Processing Record 26 for: churapcha,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=churapcha%2Cru
# Processing Record 27 for: sakakah,sa
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sakakah%2Csa
# Processing Record 28 for: beira,mz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=beira%2Cmz
# Processing Record 29 for: coquimbo,cl
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=coquimbo%2Ccl
# Processing Record 30 for: qasigiannguit,gl
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=qasigiannguit%2Cgl
# Processing Record 31 for: gunjur,gm
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=gunjur%2Cgm
# Processing Record 32 for: lawrenceburg,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=lawrenceburg%2Cus
# Processing Record 33 for: elbistan,tr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=elbistan%2Ctr
# Processing Record 34 for: ampanihy,mg
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ampanihy%2Cmg
# Processing Record 35 for: nikolskoye,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=nikolskoye%2Cru
# Processing Record 36 for: victoria,sc
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=victoria%2Csc
# Processing Record 37 for: canico,pt
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=canico%2Cpt
# Processing Record 38 for: attawapiskat,ca
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=attawapiskat%2Cca
# Processing Record 39 for: sentyabrskiy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sentyabrskiy%2Cru
# Processing Record 40 for: idlib,sy
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=idlib%2Csy
# Processing Record 41 for: kibre mengist,et
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kibre+mengist%2Cet
# Processing Record 42 for: dhidhdhoo,mv
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=dhidhdhoo%2Cmv
# Processing Record 43 for: pizarro,co
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=pizarro%2Cco
# Processing Record 44 for: bowen,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bowen%2Cau
# Processing Record 45 for: barra do bugres,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=barra+do+bugres%2Cbr
# Processing Record 46 for: evinayong,gq
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=evinayong%2Cgq
# Processing Record 47 for: sapa,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sapa%2Cph
# Processing Record 48 for: winnemucca,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=winnemucca%2Cus
# Processing Record 49 for: doka,sd
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=doka%2Csd
# Processing Record 50 for: bandarbeyla,so
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bandarbeyla%2Cso
# Processing Record 51 for: san juan bautista,py
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=san+juan+bautista%2Cpy
# Processing Record 52 for: gympie,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=gympie%2Cau
# Processing Record 53 for: santa marinella,it
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=santa+marinella%2Cit
# Processing Record 54 for: perris,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=perris%2Cus
# Processing Record 55 for: hihifo,to
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=hihifo%2Cto
# Processing Record 56 for: kirkuk,iq
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kirkuk%2Ciq
# Processing Record 57 for: farah,af
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=farah%2Caf
# Processing Record 58 for: herat,af
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=herat%2Caf
# Processing Record 59 for: pechenga,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=pechenga%2Cru
# Processing Record 60 for: fukue,jp
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=fukue%2Cjp
# Processing Record 61 for: humaita,py
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=humaita%2Cpy
# Processing Record 62 for: xai-xai,mz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=xai-xai%2Cmz
# Processing Record 63 for: kalawit,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kalawit%2Cph
# Processing Record 64 for: baghdad,iq
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=baghdad%2Ciq
# Processing Record 65 for: rochester,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=rochester%2Cus
# Processing Record 66 for: gladstone,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=gladstone%2Cau
# Processing Record 67 for: kloulklubed,pw
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kloulklubed%2Cpw
# Processing Record 68 for: apatou,gf
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=apatou%2Cgf
# Processing Record 69 for: formosa,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=formosa%2Cbr
# Processing Record 70 for: abonnema,ng
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=abonnema%2Cng
# Processing Record 71 for: tsiroanomandidy,mg
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=tsiroanomandidy%2Cmg
# Processing Record 72 for: sylacauga,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sylacauga%2Cus
# Processing Record 73 for: xifeng,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=xifeng%2Ccn
# Processing Record 74 for: yanji,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=yanji%2Ccn
# Processing Record 75 for: gornopravdinsk,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=gornopravdinsk%2Cru
# Processing Record 76 for: kingaroy,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kingaroy%2Cau
# Processing Record 77 for: mallama,co
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=mallama%2Cco
# Processing Record 78 for: benin,ng
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=benin%2Cng
# Processing Record 79 for: bargal,so
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bargal%2Cso
# Processing Record 80 for: ponta delgada,pt
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ponta+delgada%2Cpt
# Processing Record 81 for: marystown,ca
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=marystown%2Cca
# Processing Record 82 for: pilar,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=pilar%2Cph
# Processing Record 83 for: chuguyevka,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=chuguyevka%2Cru
# Processing Record 84 for: warri,ng
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=warri%2Cng
# Processing Record 85 for: gilgit,pk
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=gilgit%2Cpk
# Processing Record 86 for: mahebourg,mu
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=mahebourg%2Cmu
# Processing Record 87 for: candelaria,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=candelaria%2Cbr
# Processing Record 88 for: vallenar,cl
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=vallenar%2Ccl
# Processing Record 89 for: lodeynoye pole,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=lodeynoye+pole%2Cru
# Processing Record 90 for: kampong thum,kh
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kampong+thum%2Ckh
# Processing Record 91 for: dandong,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=dandong%2Ccn
# Processing Record 92 for: kingsport,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kingsport%2Cus
# Processing Record 93 for: potsdam,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=potsdam%2Cus
# Processing Record 94 for: cartagena,co
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=cartagena%2Cco
# Processing Record 95 for: pontian kecil,my
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=pontian+kecil%2Cmy
# Processing Record 96 for: amderma,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=amderma%2Cru
# Processing Record 97 for: laguna,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=laguna%2Cbr
# Processing Record 98 for: blythe,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=blythe%2Cus
# Processing Record 99 for: songjianghe,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=songjianghe%2Ccn
# Processing Record 100 for: dabat,et
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=dabat%2Cet
# Processing Record 101 for: dalbandin,pk
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=dalbandin%2Cpk
# Processing Record 102 for: ust-maya,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ust-maya%2Cru
# Processing Record 103 for: anloga,gh
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=anloga%2Cgh
# Processing Record 104 for: birin,dz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=birin%2Cdz
# Processing Record 105 for: ler,sd
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ler%2Csd
# Processing Record 106 for: jinotega,ni
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=jinotega%2Cni
# Processing Record 107 for: lazaro cardenas,mx
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=lazaro+cardenas%2Cmx
# Processing Record 108 for: vila velha,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=vila+velha%2Cbr
# Processing Record 109 for: belmonte,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=belmonte%2Cbr
# Processing Record 110 for: aasiaat,gl
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=aasiaat%2Cgl
# Processing Record 111 for: boa vista,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=boa+vista%2Cbr
# Processing Record 112 for: sao joao da barra,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sao+joao+da+barra%2Cbr
# Processing Record 113 for: aklavik,ca
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=aklavik%2Cca
# Processing Record 114 for: manjacaze,mz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=manjacaze%2Cmz
# Processing Record 115 for: wum,cm
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=wum%2Ccm
# Processing Record 116 for: half moon bay,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=half+moon+bay%2Cus
# Processing Record 117 for: teahupoo,pf
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=teahupoo%2Cpf
# Processing Record 118 for: vagamo,no
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=vagamo%2Cno
# Processing Record 119 for: aflu,dz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=aflu%2Cdz
# Processing Record 120 for: laguna de perlas,ni
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=laguna+de+perlas%2Cni
# Processing Record 121 for: hirado,jp
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=hirado%2Cjp
# Processing Record 122 for: ilulissat,gl
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ilulissat%2Cgl
# Processing Record 123 for: navabad,tj
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=navabad%2Ctj
# Processing Record 124 for: stekolnyy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=stekolnyy%2Cru
# Processing Record 125 for: boulder city,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=boulder+city%2Cus
# Processing Record 126 for: tank,pk
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=tank%2Cpk
# Processing Record 127 for: umm ruwabah,sd
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=umm+ruwabah%2Csd
# Processing Record 128 for: kristinehamn,se
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kristinehamn%2Cse
# Processing Record 129 for: san isidro,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=san+isidro%2Cph
# Processing Record 130 for: kulhudhuffushi,mv
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kulhudhuffushi%2Cmv
# Processing Record 131 for: richmond hill,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=richmond+hill%2Cus
# Processing Record 132 for: ugoofaaru,mv
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ugoofaaru%2Cmv
# Processing Record 133 for: isiolo,ke
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=isiolo%2Cke
# Processing Record 134 for: tallahassee,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=tallahassee%2Cus
# Processing Record 135 for: rabak,sd
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=rabak%2Csd
# Processing Record 136 for: henties bay,na
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=henties+bay%2Cna
# Processing Record 137 for: yenagoa,ng
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=yenagoa%2Cng
# Processing Record 138 for: bredasdorp,za
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bredasdorp%2Cza
# Processing Record 139 for: saraland,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=saraland%2Cus
# Processing Record 140 for: qaanaaq,gl
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=qaanaaq%2Cgl
# Processing Record 141 for: along,in
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=along%2Cin
# Processing Record 142 for: jaciara,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=jaciara%2Cbr
# Processing Record 143 for: paralimni,cy
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=paralimni%2Ccy
# Processing Record 144 for: torbay,ca
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=torbay%2Cca
# Processing Record 145 for: seydi,tm
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=seydi%2Ctm
# Processing Record 146 for: edgewater,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=edgewater%2Cus
# Processing Record 147 for: bairiki,ki
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bairiki%2Cki
# Processing Record 148 for: tianpeng,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=tianpeng%2Ccn
# Processing Record 149 for: ningan,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ningan%2Ccn
# Processing Record 150 for: tasbuget,kz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=tasbuget%2Ckz
# Processing Record 151 for: kudahuvadhoo,mv
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kudahuvadhoo%2Cmv
# Processing Record 152 for: vilyuysk,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=vilyuysk%2Cru
# Processing Record 153 for: severodvinsk,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=severodvinsk%2Cru
# Processing Record 154 for: salinopolis,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=salinopolis%2Cbr
# Processing Record 155 for: talah,tn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=talah%2Ctn
# Processing Record 156 for: sarangani,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sarangani%2Cph
# Processing Record 157 for: sai buri,th
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sai+buri%2Cth
# Processing Record 158 for: mattru,sl
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=mattru%2Csl
# Processing Record 159 for: ballitoville,za
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ballitoville%2Cza
# Processing Record 160 for: pasighat,in
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=pasighat%2Cin
# Processing Record 161 for: rawah,iq
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=rawah%2Ciq
# Processing Record 162 for: mount gambier,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=mount+gambier%2Cau
# Processing Record 163 for: zvishavane,zw
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=zvishavane%2Czw
# Processing Record 164 for: ko samui,th
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ko+samui%2Cth
# Processing Record 165 for: videira,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=videira%2Cbr
# Processing Record 166 for: ypsonas,cy
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ypsonas%2Ccy
# Processing Record 167 for: staunton,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=staunton%2Cus
# Processing Record 168 for: port lincoln,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=port+lincoln%2Cau
# Processing Record 169 for: praia,cv
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=praia%2Ccv
# Processing Record 170 for: hailey,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=hailey%2Cus
# Processing Record 171 for: bayir,jo
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bayir%2Cjo
# Processing Record 172 for: qandahar,af
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=qandahar%2Caf
# Processing Record 173 for: melbu,no
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=melbu%2Cno
# Processing Record 174 for: eureka,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=eureka%2Cus
# Processing Record 175 for: ballina,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ballina%2Cau
# Processing Record 176 for: save,bj
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=save%2Cbj
# Processing Record 177 for: belushya guba,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=belushya+guba%2Cru
# Processing Record 178 for: dir,pk
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=dir%2Cpk
# Processing Record 179 for: leningradskiy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=leningradskiy%2Cru
# Processing Record 180 for: isla vista,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=isla+vista%2Cus
# Processing Record 181 for: ninghai,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ninghai%2Ccn
# Processing Record 182 for: gravdal,no
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=gravdal%2Cno
# Processing Record 183 for: arraial do cabo,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=arraial+do+cabo%2Cbr
# Processing Record 184 for: shenjiamen,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=shenjiamen%2Ccn
# Processing Record 185 for: perpignan,fr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=perpignan%2Cfr
# Processing Record 186 for: sugod,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sugod%2Cph
# Processing Record 187 for: pangody,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=pangody%2Cru
# Processing Record 188 for: el dovio,co
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=el+dovio%2Cco
# Processing Record 189 for: pyaozerskiy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=pyaozerskiy%2Cru
# Processing Record 190 for: gazojak,tm
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=gazojak%2Ctm
# Processing Record 191 for: solovetskiy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=solovetskiy%2Cru
# Processing Record 192 for: pokrovsk,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=pokrovsk%2Cru
# Processing Record 193 for: zapolyarnyy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=zapolyarnyy%2Cru
# Processing Record 194 for: santa cruz,cr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=santa+cruz%2Ccr
# Processing Record 195 for: ngukurr,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ngukurr%2Cau
# Processing Record 196 for: tucuma,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=tucuma%2Cbr
# Processing Record 197 for: san lazaro,py
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=san+lazaro%2Cpy
# Processing Record 198 for: tigzirt,dz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=tigzirt%2Cdz
# Processing Record 199 for: asadabad,af
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=asadabad%2Caf
# Processing Record 200 for: huanren,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=huanren%2Ccn
# Processing Record 201 for: lavrentiya,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=lavrentiya%2Cru
# Processing Record 202 for: deyang,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=deyang%2Ccn
# Processing Record 203 for: klaebu,no
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=klaebu%2Cno
# Processing Record 204 for: asayita,et
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=asayita%2Cet
# Processing Record 205 for: zaltan,ly
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=zaltan%2Cly
# Processing Record 206 for: saint george,bm
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=saint+george%2Cbm
# Processing Record 207 for: zabid,ye
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=zabid%2Cye
# Processing Record 208 for: sakaiminato,jp
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sakaiminato%2Cjp
# Processing Record 209 for: ales,fr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ales%2Cfr
# Processing Record 210 for: urumqi,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=urumqi%2Ccn
# Processing Record 211 for: maxixe,mz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=maxixe%2Cmz
# Processing Record 212 for: sao borja,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sao+borja%2Cbr
# Processing Record 213 for: jubayl,lb
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=jubayl%2Clb
# Processing Record 214 for: barentsburg,sj
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=barentsburg%2Csj
# Processing Record 215 for: jiancheng,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=jiancheng%2Ccn
# Processing Record 216 for: berlevag,no
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=berlevag%2Cno
# Processing Record 217 for: kumi,ug
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kumi%2Cug
# Processing Record 218 for: rena,no
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=rena%2Cno
# Processing Record 219 for: natitingou,bj
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=natitingou%2Cbj
# Processing Record 220 for: araceli,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=araceli%2Cph
# Processing Record 221 for: sungai kolok,th
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sungai+kolok%2Cth
# Processing Record 222 for: makakilo city,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=makakilo+city%2Cus
# Processing Record 223 for: college,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=college%2Cus
# Processing Record 224 for: barcelona,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=barcelona%2Cph
# Processing Record 225 for: ossora,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ossora%2Cru
# Processing Record 226 for: thinadhoo,mv
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=thinadhoo%2Cmv
# Processing Record 227 for: barstow,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=barstow%2Cus
# Processing Record 228 for: cherskiy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=cherskiy%2Cru
# Processing Record 229 for: palana,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=palana%2Cru
# Processing Record 230 for: vladivostok,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=vladivostok%2Cru
# Processing Record 231 for: oussouye,sn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=oussouye%2Csn
# Processing Record 232 for: corum,tr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=corum%2Ctr
# Processing Record 233 for: buenaventura,co
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=buenaventura%2Cco
# Processing Record 234 for: prattville,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=prattville%2Cus
# Processing Record 235 for: pitogo,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=pitogo%2Cph
# Processing Record 236 for: sorland,no
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sorland%2Cno
# Processing Record 237 for: kurume,jp
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kurume%2Cjp
# Processing Record 238 for: zaria,ng
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=zaria%2Cng
# Processing Record 239 for: oka,ng
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=oka%2Cng
# Processing Record 240 for: novorossiysk,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=novorossiysk%2Cru
# Processing Record 241 for: vardo,no
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=vardo%2Cno
# Processing Record 242 for: gombe,ng
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=gombe%2Cng
# Processing Record 243 for: bubaque,gw
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bubaque%2Cgw
# Processing Record 244 for: mulanje,mw
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=mulanje%2Cmw
# Processing Record 245 for: dujuma,so
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=dujuma%2Cso
# Processing Record 246 for: pisco,pe
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=pisco%2Cpe
# Processing Record 247 for: nakhon nayok,th
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=nakhon+nayok%2Cth
# Processing Record 248 for: bajo baudo,co
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=bajo+baudo%2Cco
# Processing Record 249 for: midyat,tr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=midyat%2Ctr
# Processing Record 250 for: petersburg,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=petersburg%2Cus
# Processing Record 251 for: tubuala,pa
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=tubuala%2Cpa
# Processing Record 252 for: sakaraha,mg
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sakaraha%2Cmg
# Processing Record 253 for: jammu,in
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=jammu%2Cin
# Processing Record 254 for: xining,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=xining%2Ccn
# Processing Record 255 for: pousat,kh
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=pousat%2Ckh
# Processing Record 256 for: hofn,is
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=hofn%2Cis
# Processing Record 257 for: labuhan,id
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=labuhan%2Cid
# Processing Record 258 for: roald,no
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=roald%2Cno
# Processing Record 259 for: kulu,tr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kulu%2Ctr
# Processing Record 260 for: barra do garcas,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=barra+do+garcas%2Cbr
# Processing Record 261 for: ribeira grande,pt
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ribeira+grande%2Cpt
# Processing Record 262 for: mardin,tr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=mardin%2Ctr
# Processing Record 263 for: dukat,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=dukat%2Cru
# Processing Record 264 for: opuwo,na
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=opuwo%2Cna
# Processing Record 265 for: gazli,uz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=gazli%2Cuz
# Processing Record 266 for: kulachi,pk
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kulachi%2Cpk
# Processing Record 267 for: pozo colorado,py
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=pozo+colorado%2Cpy
# Processing Record 268 for: puerto quijarro,bo
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=puerto+quijarro%2Cbo
# Processing Record 269 for: valparaiso,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=valparaiso%2Cbr
# Processing Record 270 for: yaan,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=yaan%2Ccn
# Processing Record 271 for: manzil salim,tn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=manzil+salim%2Ctn
# Processing Record 272 for: oxford,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=oxford%2Cus
# Processing Record 273 for: rio verde de mato grosso,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=rio+verde+de+mato+grosso%2Cbr
# Processing Record 274 for: syamzha,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=syamzha%2Cru
# Processing Record 275 for: adwa,et
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=adwa%2Cet
# Processing Record 276 for: sidi bu zayd,tn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sidi+bu+zayd%2Ctn
# Processing Record 277 for: vreed en hoop,gy
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=vreed+en+hoop%2Cgy
# Processing Record 278 for: fredericksburg,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=fredericksburg%2Cus
# Processing Record 279 for: dromolaxia,cy
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=dromolaxia%2Ccy
# Processing Record 280 for: dikson,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=dikson%2Cru
# Processing Record 281 for: kuang,my
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kuang%2Cmy
# Processing Record 282 for: ilinskiy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ilinskiy%2Cru
# Processing Record 283 for: werota,et
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=werota%2Cet
# Processing Record 284 for: burica,pa
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=burica%2Cpa
# Processing Record 285 for: onega,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=onega%2Cru
# Processing Record 286 for: yeletskiy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=yeletskiy%2Cru
# Processing Record 287 for: lalomanu,ws
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=lalomanu%2Cws
# Processing Record 288 for: tahoua,ne
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=tahoua%2Cne
# Processing Record 289 for: poya,nc
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=poya%2Cnc
# Processing Record 290 for: hami,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=hami%2Ccn
# Processing Record 291 for: puerto cabezas,ni
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=puerto+cabezas%2Cni
# Processing Record 292 for: shaartuz,tj
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=shaartuz%2Ctj
# Processing Record 293 for: husavik,is
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=husavik%2Cis
# Processing Record 294 for: mys shmidta,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=mys+shmidta%2Cru
# Processing Record 295 for: peniche,pt
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=peniche%2Cpt
# Processing Record 296 for: mount darwin,zw
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=mount+darwin%2Czw
# Processing Record 297 for: taft,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=taft%2Cus
# Processing Record 298 for: sigli,id
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sigli%2Cid
# Processing Record 299 for: iracoubo,gf
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=iracoubo%2Cgf
# Processing Record 300 for: halalo,wf
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=halalo%2Cwf
# Processing Record 301 for: brawley,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=brawley%2Cus
# Processing Record 302 for: lokosovo,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=lokosovo%2Cru
# Processing Record 303 for: port hedland,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=port+hedland%2Cau
# Processing Record 304 for: anan,jp
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=anan%2Cjp
# Processing Record 305 for: albany,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=albany%2Cau
# Processing Record 306 for: show low,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=show+low%2Cus
# Processing Record 307 for: ayer itam,my
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ayer+itam%2Cmy
# Processing Record 308 for: tezu,in
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=tezu%2Cin
# Processing Record 309 for: sinnamary,gf
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sinnamary%2Cgf
# Processing Record 310 for: burewala,pk
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=burewala%2Cpk
# Processing Record 311 for: batken,kg
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=batken%2Ckg
# Processing Record 312 for: gua musang,my
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=gua+musang%2Cmy
# Processing Record 313 for: romitan,uz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=romitan%2Cuz
# Processing Record 314 for: hunza,pk
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=hunza%2Cpk
# Processing Record 315 for: nichinan,jp
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=nichinan%2Cjp
# Processing Record 316 for: kirakira,sb
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kirakira%2Csb
# Processing Record 317 for: joao pinheiro,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=joao+pinheiro%2Cbr
# Processing Record 318 for: glenwood springs,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=glenwood+springs%2Cus
# Processing Record 319 for: gallup,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=gallup%2Cus
# Processing Record 320 for: nioaque,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=nioaque%2Cbr
# Processing Record 321 for: lira,ug
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=lira%2Cug
# Processing Record 322 for: ternate,id
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ternate%2Cid
# Processing Record 323 for: sukhumi,ge
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sukhumi%2Cge
# Processing Record 324 for: cassilandia,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=cassilandia%2Cbr
# Processing Record 325 for: fukuma,jp
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=fukuma%2Cjp
# Processing Record 326 for: tsihombe,mg
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=tsihombe%2Cmg
# Processing Record 327 for: dongning,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=dongning%2Ccn
# Processing Record 328 for: kathu,th
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kathu%2Cth
# Processing Record 329 for: chubbuck,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=chubbuck%2Cus
# Processing Record 330 for: camopi,gf
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=camopi%2Cgf
# Processing Record 331 for: vila do maio,cv
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=vila+do+maio%2Ccv
# Processing Record 332 for: tupa,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=tupa%2Cbr
# Processing Record 333 for: kieta,pg
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kieta%2Cpg
# Processing Record 334 for: kitob,uz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kitob%2Cuz
# Processing Record 335 for: anicuns,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=anicuns%2Cbr
# Processing Record 336 for: tuggurt,dz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=tuggurt%2Cdz
# Processing Record 337 for: mutis,co
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=mutis%2Cco
# Processing Record 338 for: nome,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=nome%2Cus
# Processing Record 339 for: santa vitoria,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=santa+vitoria%2Cbr
# Processing Record 340 for: manado,id
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=manado%2Cid
# Processing Record 341 for: sibolga,id
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sibolga%2Cid
# Processing Record 342 for: chumphon,th
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=chumphon%2Cth
# Processing Record 343 for: rantoul,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=rantoul%2Cus
# Processing Record 344 for: berbera,so
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=berbera%2Cso
# Processing Record 345 for: tuktoyaktuk,ca
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=tuktoyaktuk%2Cca
# Processing Record 346 for: pafos,cy
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=pafos%2Ccy
# Processing Record 347 for: concordia,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=concordia%2Cbr
# Processing Record 348 for: tazovskiy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=tazovskiy%2Cru
# Processing Record 349 for: edd,er
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=edd%2Cer
# Processing Record 350 for: surin,th
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=surin%2Cth
# Processing Record 351 for: scarborough,tt
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=scarborough%2Ctt
# Processing Record 352 for: abong mbang,cm
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=abong+mbang%2Ccm
# Processing Record 353 for: richards bay,za
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=richards+bay%2Cza
# Processing Record 354 for: banda aceh,id
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=banda+aceh%2Cid
# Processing Record 355 for: ponta do sol,pt
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ponta+do+sol%2Cpt
# Processing Record 356 for: garh maharaja,pk
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=garh+maharaja%2Cpk
# Processing Record 357 for: monrovia,lr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=monrovia%2Clr
# Processing Record 358 for: agua blanca,gt
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=agua+blanca%2Cgt
# Processing Record 359 for: abu kamal,sy
# ...
# Processing Record 482 for: oytal,kz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=oytal%2Ckz
# Processing Record 483 for: sayat,tm
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sayat%2Ctm
# Processing Record 484 for: eskasem,af
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=eskasem%2Caf
# Processing Record 485 for: beckley,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=beckley%2Cus
# Processing Record 486 for: raudeberg,no
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=raudeberg%2Cno
# Processing Record 487 for: diffa,ne
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=diffa%2Cne
# Processing Record 488 for: nieuw amsterdam,sr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=nieuw+amsterdam%2Csr
# Processing Record 489 for: morondava,mg
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=morondava%2Cmg
# Processing Record 490 for: alamosa,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=alamosa%2Cus
# Processing Record 491 for: staryy nadym,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=staryy+nadym%2Cru
# Processing Record 492 for: lancaster,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=lancaster%2Cus
# Processing Record 493 for: cabras,it
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=cabras%2Cit
# Processing Record 494 for: tiksi,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=tiksi%2Cru
# Processing Record 495 for: sainte-maxime,fr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sainte-maxime%2Cfr
# Processing Record 496 for: waipawa,nz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=waipawa%2Cnz
# Processing Record 497 for: ron phibun,th
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ron+phibun%2Cth
# Processing Record 498 for: pulaski,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=pulaski%2Cus
# Processing Record 499 for: ankpa,ng
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ankpa%2Cng
# Processing Record 500 for: mumford,gh
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=mumford%2Cgh
# Processing Record 501 for: makokou,ga
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=makokou%2Cga
# Processing Record 502 for: ardahan,tr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ardahan%2Ctr
# Processing Record 503 for: kahului,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kahului%2Cus
# Processing Record 504 for: torit,sd
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=torit%2Csd
# Processing Record 505 for: lazi,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=lazi%2Cph
# Processing Record 506 for: beipiao,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=beipiao%2Ccn
# Processing Record 507 for: totness,sr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=totness%2Csr
# Processing Record 508 for: yabelo,et
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=yabelo%2Cet
# Processing Record 509 for: port keats,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=port+keats%2Cau
# Processing Record 510 for: sterling,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sterling%2Cus
# Processing Record 511 for: naco,mx
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=naco%2Cmx
# Processing Record 512 for: eydhafushi,mv
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=eydhafushi%2Cmv
# Processing Record 513 for: cotonou,bj
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=cotonou%2Cbj
# Processing Record 514 for: waycross,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=waycross%2Cus
# Processing Record 515 for: rayong,th
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=rayong%2Cth
# Processing Record 516 for: satun,th
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=satun%2Cth
# Processing Record 517 for: assela,et
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=assela%2Cet
# Processing Record 518 for: imbituba,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=imbituba%2Cbr
# Processing Record 519 for: khandyga,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=khandyga%2Cru
# Processing Record 520 for: hendek,tr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=hendek%2Ctr
# Processing Record 521 for: talaya,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=talaya%2Cru
# Processing Record 522 for: spartanburg,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=spartanburg%2Cus
# Processing Record 523 for: karauzyak,uz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=karauzyak%2Cuz
# Processing Record 524 for: diapaga,bf
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=diapaga%2Cbf
# Processing Record 525 for: beringovskiy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=beringovskiy%2Cru
# Processing Record 526 for: san policarpo,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=san+policarpo%2Cph
# Processing Record 527 for: dahuk,iq
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=dahuk%2Ciq
# Processing Record 528 for: banyo,cm
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=banyo%2Ccm
# Processing Record 529 for: boditi,et
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=boditi%2Cet
# Processing Record 530 for: winchester,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=winchester%2Cus
# Processing Record 531 for: hede,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=hede%2Ccn
# Processing Record 532 for: rikitea,pf
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=rikitea%2Cpf
# Processing Record 533 for: san cristobal,ec
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=san+cristobal%2Cec
# Processing Record 534 for: batman,tr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=batman%2Ctr
# Processing Record 535 for: hakkari,tr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=hakkari%2Ctr
# Processing Record 536 for: port hueneme,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=port+hueneme%2Cus
# Processing Record 537 for: touros,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=touros%2Cbr
# Processing Record 538 for: hervey bay,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=hervey+bay%2Cau
# Processing Record 539 for: portland,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=portland%2Cau
# Processing Record 540 for: rio do sul,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=rio+do+sul%2Cbr
# Processing Record 541 for: murgab,tm
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=murgab%2Ctm
# Processing Record 542 for: chuy,uy
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=chuy%2Cuy
# Processing Record 543 for: sabibah,tn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sabibah%2Ctn
# Processing Record 544 for: lagoa vermelha,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=lagoa+vermelha%2Cbr
# Processing Record 545 for: cortez,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=cortez%2Cus
# Processing Record 546 for: saleaula,ws
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=saleaula%2Cws
# Processing Record 547 for: pinega,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=pinega%2Cru
# Processing Record 548 for: jaramana,sy
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=jaramana%2Csy
# Processing Record 549 for: quelimane,mz
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=quelimane%2Cmz
# Processing Record 550 for: trapani,it
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=trapani%2Cit
# Processing Record 551 for: alice springs,au
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=alice+springs%2Cau
# Processing Record 552 for: virginia beach,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=virginia+beach%2Cus
# Processing Record 553 for: port-gentil,ga
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=port-gentil%2Cga
# Processing Record 554 for: ipora,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ipora%2Cbr
# Processing Record 555 for: arinos,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=arinos%2Cbr
# Processing Record 556 for: airai,pw
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=airai%2Cpw
# Processing Record 557 for: uyemskiy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=uyemskiy%2Cru
# Processing Record 558 for: mar del plata,ar
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=mar+del+plata%2Car
# Processing Record 559 for: kuloy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kuloy%2Cru
# Processing Record 560 for: fortuna,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=fortuna%2Cus
# Processing Record 561 for: sunrise manor,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sunrise+manor%2Cus
# Processing Record 562 for: viransehir,tr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=viransehir%2Ctr
# Processing Record 563 for: naranjal,py
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=naranjal%2Cpy
# Processing Record 564 for: quballat,tn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=quballat%2Ctn
# Processing Record 565 for: sunbury,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=sunbury%2Cus
# Processing Record 566 for: mondlo,za
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=mondlo%2Cza
# Processing Record 567 for: iguape,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=iguape%2Cbr
# Processing Record 568 for: manokwari,id
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=manokwari%2Cid
# Processing Record 569 for: souillac,mu
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=souillac%2Cmu
# Processing Record 570 for: ridgecrest,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ridgecrest%2Cus
# Processing Record 571 for: marabba,sd
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=marabba%2Csd
# Processing Record 572 for: necochea,ar
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=necochea%2Car
# Processing Record 573 for: agirish,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=agirish%2Cru
# Processing Record 574 for: atuona,pf
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=atuona%2Cpf
# Processing Record 575 for: amapa,br
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=amapa%2Cbr
# Processing Record 576 for: okitipupa,ng
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=okitipupa%2Cng
# Processing Record 577 for: kijang,id
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kijang%2Cid
# Processing Record 578 for: palmas bellas,pa
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=palmas+bellas%2Cpa
# Processing Record 579 for: onverwacht,sr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=onverwacht%2Csr
# Processing Record 580 for: minna,ng
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=minna%2Cng
# Processing Record 581 for: saint marys,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=saint+marys%2Cus
# Processing Record 582 for: brandon,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=brandon%2Cus
# Processing Record 583 for: cherkessk,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=cherkessk%2Cru
# Processing Record 584 for: georgetown,sh
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=georgetown%2Csh
# Processing Record 585 for: puerto ayora,ec
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=puerto+ayora%2Cec
# Processing Record 586 for: wheeling,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=wheeling%2Cus
# Processing Record 587 for: dakoro,ne
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=dakoro%2Cne
# Processing Record 588 for: baykit,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=baykit%2Cru
# Processing Record 589 for: worland,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=worland%2Cus
# Processing Record 590 for: kapaa,us
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=kapaa%2Cus
# Processing Record 591 for: butaritari,ki
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=butaritari%2Cki
# Processing Record 592 for: khorixas,na
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=khorixas%2Cna
# Processing Record 593 for: shambu,et
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=shambu%2Cet
# Processing Record 594 for: ercis,tr
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=ercis%2Ctr
# Processing Record 595 for: taolanaro,mg
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=taolanaro%2Cmg
# Processing Record 596 for: zhuanghe,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=zhuanghe%2Ccn
# Processing Record 597 for: omsukchan,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=omsukchan%2Cru
# Processing Record 598 for: doume,cm
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=doume%2Ccm
# Processing Record 599 for: hermanus,za
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=hermanus%2Cza
# Processing Record 600 for: mormugao,in
# http://api.openweathermap.org/data/2.5/weather?appid=<NoSeeMyKey>&units=metric&q=mormugao%2Cin

# %%
# Drop cities with missing information and create csv file
random_cities = random_cities.dropna()
random_cities.to_csv("city_weather_data.csv")
print(random_cities.shape)
random_cities.head()
# Out:
# (523, 8)
#   Closest City Country Code  Latitude  Longitude  Temperature  Wind Speed  \
# 0         jand           pk     33.43      72.02        13.85        1.22
# 1  san lorenzo           ar    -24.73     -65.49        20.00        1.50
# 2     mosquera           co      4.71     -74.23        19.00        4.10
# 3        wajid           so      3.81      43.25        27.27        5.52
# 4    upernavik           gl     72.79     -56.15       -20.41        2.87
#
#    Humidity  Cloudiness
# 0     100.0         0.0
# 1      55.0        75.0
# 2      63.0        40.0
# 3      60.0         0.0
# 4      94.0        20.0

# %% [markdown]
# # Scatterplots to visualize data for data analysis
#
#
#
#
# # Maximum Temperature versus Latitude

# %%
# Temperature vs Latitude 
random_cities.plot(kind="scatter",x="Latitude",y="Temperature",grid=True,color="blue")
plt.title(" Maximum Temperature (Celcius) versus Latitude")
plt.ylabel("Maximum Temperature (Celcius)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-90,90])
plt.axvline(0, color='black',alpha=0.5)
plt.savefig("Maximum Temperature vs Latitude")
plt.show()

# %% [markdown]
# # Maximum Temperature versus Latitude - Observations
# Temperatures do tend to be higher in cities that are closer to the equator.  You can see a downward trend in temperatures the farther away to go from the equator, especially in the northern hemisphere.  There are more cities in the sample population that are closer to the north pole compared to the south pole, which is likely because there are more cities in the northern hemisphere.
#
#
# # Humidity versus Latitude

# %%
# Humidity vs Latitude 

random_cities.plot(kind="scatter",x="Latitude",y="Humidity",grid=True,color="blue")
plt.title("Humidity versus Latitude")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-90,90])
plt.axvline(0, color='black',alpha=0.5)
plt.savefig("Humidity vs Latitude")
plt.show()

# %% [markdown]
# # Humidity versus Latitude - Observations
# In this sample population there does appear to be a slight trend that the farther away from the equator, the lowest humidity levels tend to increase.  As this trend is very slight there could be some population bias.
#
#
# # Wind Speed versus Latitude

# %%
# Wind Speed vs Latitude
random_cities["Wind Speed"] = pd.to_numeric(random_cities["Wind Speed"])
random_cities.plot(kind="scatter",x="Latitude",y="Wind Speed",grid=True,color="blue")
plt.title("Wind Spead versus Latitude")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-90,90])
plt.axvline(0, color='black',alpha=0.5)
plt.savefig("Wind speed vs Latitude")
plt.show()

# %% [markdown]
# # Wind Speed versus Latitude - Observations
# There does not appear to be a significant change in wind speed based on distace from the equator.  Generally, wind speeds are consistently below 10 KPH.  There are a few values over 10 KPH the farther away from the equator you go; however, there are very few and these could be outliers.
#
#
# # Cloudiness versus Latitude

# %%
# Cloudiness vs Latitude
random_cities["Cloudiness"] = pd.to_numeric(random_cities["Cloudiness"])
random_cities.plot(kind="scatter",x="Latitude",y="Cloudiness",grid=True,color="blue")
plt.title("Cloudiness versus Latitude")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-90,90])
plt.axvline(0, color='black',alpha=0.5)
plt.savefig("Cloudiness vs Latitude")
plt.show()

# %% [markdown]
# # Cloudiness versus Latitude - Observations
# No significant trends can be seen in the data for this sample population.  Distance from the equator does not appear to be a factor in cloudiness.
